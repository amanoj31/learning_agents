# %% [markdown]
# # L1: Automated Project: Planning, Estimation, and Allocation

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

import os
import yaml
from crewai import Agent, Task, Crew

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>

# %% [markdown]
# ## Set OpenAI Model

# %%
os.environ['OPENAI_MODEL_NAME'] = 'gpt-4o-mini'

# %% [markdown]
# ## Loading Tasks and Agents YAML files

# %%
# Define file paths for YAML configurations
files = {
    'agents': 'config/agents.yaml',
    'tasks': 'config/tasks.yaml'
}

# Load configurations from YAML files
configs = {}
for config_type, file_path in files.items():
    with open(file_path, 'r') as file:
        configs[config_type] = yaml.safe_load(file)

# Assign loaded configurations to specific variables
agents_config = configs['agents']
tasks_config = configs['tasks']

# %%
display(agents_config)
# Out:
# {'project_planning_agent': {'role': 'The Ultimate Project Planner\n',
#   'goal': 'To meticulously break down the {project_type} project into actionable tasks, ensuring no detail is overlooked, and setting precise timelines that align with the {project_objectives}.\n',
#   'backstory': "As a veteran project manager, you’ve led numerous successful projects, particularly in {industry}. Your keen eye for detail and strategic thinking have always ensured that projects are delivered on time and within scope. Now, you're tasked with planning the next groundbreaking {project_type} project.\n",
#   'allow_delegation': False,
#   'verbose': True},
#  'estimation_agent': {'role': 'Expert Estimation Analyst\n',
#   'goal': 'Provide highly accurate time, resource, and effort estimations for each task in the {project_type} project to ensure it is delivered efficiently and on budget.\n',
#   'backstory': 'You are the go-to expert for project estimation in {industry}. With a wealth of experience and access to vast historical data, you can predict the resources required for any task with remarkable accuracy. Your precision ensures that the {project_type} project remains feasible and avoids unnecessary delays or budget overruns.\n',
#   'allow_delegation': False,
#   'verbose': True},
#  'resource_allocation_agent': {'role': 'Resource Allocation Strategist\n',
#   'goal': "Optimize the allocation of tasks for the {project_type} project by balancing team members' skills, availability, and current workload to maximize efficiency and project success.\n",
#   'backstory': 'With a deep understanding of team dynamics and resource management in {industry}, you have a track record of ensuring that the right person is always assigned to the right task. Your strategic thinking ensures that the {project_type} project team is utilized to its full potential without overburdening any individual.\n',
#   'allow_delegation': False,
#   'verbose': True}}

# %%
display(tasks_config)
# Out:
# {'task_breakdown': {'description': "Carefully analyze the project_requirements for the {project_type} project and break them down into individual tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are accounted for:\n{project_requirements}\n\nTeam members:\n{team_members}\n",
#   'expected_output': 'A comprehensive list of tasks with detailed descriptions, timelines, dependencies, and deliverables. Your final output MUST include a Gantt chart or similar timeline visualization specific to the {project_type} project.\n'},
#  'time_resource_estimation': {'description': 'Thoroughly evaluate each task in the {project_type} project to estimate the time, resources, and effort required. Use historical data, task complexity, and available resources to provide a realistic estimation for each task.\n',
#   'expected_output': 'A detailed estimation report outlining the time, resources, and effort required for each task in the {project_type} project. Your final report MUST include a summary of any risks or uncertainties associated with the estimations.\n'},
#  'resource_allocation': {'description': 'Strategically allocate tasks for the {project_type} project to team members based on their skills, availability, and current workload. Ensure that each task is assigned to the most suitable team member and that the workload is evenly distributed.\n\nTeam members:\n{team_members}\n',
#   'expected_output': 'A resource allocation chart showing which team members are responsible for each task in the {project_type} project, along with start and end dates. Your final output MUST also include a summary explaining the rationale behind each allocation decision.\n'}}

# %% [markdown]
# ## Create Pydantic Models for Structured Output

# %%
from typing import List
from pydantic import BaseModel, Field

class TaskEstimate(BaseModel):
    task_name: str = Field(..., description="Name of the task")
    estimated_time_hours: float = Field(..., description="Estimated time to complete the task in hours")
    required_resources: List[str] = Field(..., description="List of resources required to complete the task")

class Milestone(BaseModel):
    milestone_name: str = Field(..., description="Name of the milestone")
    tasks: List[str] = Field(..., description="List of task IDs associated with this milestone")

class ProjectPlan(BaseModel):
    tasks: List[TaskEstimate] = Field(..., description="List of tasks with their estimates")
    milestones: List[Milestone] = Field(..., description="List of project milestones")

# %% [markdown]
# ## Create Crew, Agents and Tasks

# %%
# Creating Agents
project_planning_agent = Agent(
  config=agents_config['project_planning_agent']
)

estimation_agent = Agent(
  config=agents_config['estimation_agent']
)

resource_allocation_agent = Agent(
  config=agents_config['resource_allocation_agent']
)

# Creating Tasks
task_breakdown = Task(
  config=tasks_config['task_breakdown'],
  agent=project_planning_agent
)

time_resource_estimation = Task(
  config=tasks_config['time_resource_estimation'],
  agent=estimation_agent
)

resource_allocation = Task(
  config=tasks_config['resource_allocation'],
  agent=resource_allocation_agent,
  output_pydantic=ProjectPlan # This is the structured output we want
)

# Creating Crew
crew = Crew(
  agents=[
    project_planning_agent,
    estimation_agent,
    resource_allocation_agent
  ],
  tasks=[
    task_breakdown,
    time_resource_estimation,
    resource_allocation
  ],
  verbose=True
)

# %% [markdown]
# ## Crew's Inputs

# %%
from IPython.display import display, Markdown

project = 'Website'
industry = 'Technology'
project_objectives = 'Create a website for a small business'
team_members = """
- John Doe (Project Manager)
- Jane Doe (Software Engineer)
- Bob Smith (Designer)
- Alice Johnson (QA Engineer)
- Tom Brown (QA Engineer)
"""
project_requirements = """
- Create a responsive design that works well on desktop and mobile devices
- Implement a modern, visually appealing user interface with a clean look
- Develop a user-friendly navigation system with intuitive menu structure
- Include an "About Us" page highlighting the company's history and values
- Design a "Services" page showcasing the business's offerings with descriptions
- Create a "Contact Us" page with a form and integrated map for communication
- Implement a blog section for sharing industry news and company updates
- Ensure fast loading times and optimize for search engines (SEO)
- Integrate social media links and sharing capabilities
- Include a testimonials section to showcase customer feedback and build trust
"""

# Format the dictionary as Markdown for a better display in Jupyter Lab
formatted_output = f"""
**Project Type:** {project}

**Project Objectives:** {project_objectives}

**Industry:** {industry}

**Team Members:**
{team_members}
**Project Requirements:**
{project_requirements}
"""
# Display the formatted output as Markdown
display(Markdown(formatted_output))
# Out:
# **Project Type:** Website
#
# **Project Objectives:** Create a website for a small business
#
# **Industry:** Technology
#
# **Team Members:**
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
# **Project Requirements:**
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust

# %% [markdown]
# ## Kicking off the crew

# %%
# The given Python dictionary
inputs = {
  'project_type': project,
  'project_objectives': project_objectives,
  'industry': industry,
  'team_members': team_members,
  'project_requirements': project_requirements
}

# Run the crew
result = crew.kickoff(
  inputs=inputs
)
# Out:
# # Agent: The Ultimate Project Planner
# ## Task: Carefully analyze the project_requirements for the Website project and break them down into individual tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are accounted for:
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust
#
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: The Ultimate Project Planner
# ## Final Answer:
# ### Website Project Breakdown
#
# #### Project Title: Create a Website for a Small Business
#
# #### Team Members:
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
# ---
#
# ### Task Breakdown:
#
# 1. **Responsive Design Creation**
#    - **Description:** Develop a design that adapts seamlessly to different screen sizes (desktops, tablets, mobile devices).
#    - **Deliverable:** A responsive design prototype.
#    - **Duration:** 2 weeks
#    - **Dependencies:** None
#
# 2. **User Interface Development**
#    - **Description:** Implement a modern, visually appealing user interface with a clean look. Focus on aesthetics and usability.
#    - **Deliverable:** Finalized UI elements (buttons, forms, icons).
#    - **Duration:** 2 weeks
#    - **Dependencies:** Completion of the Responsive Design Creation
#
# 3. **Navigation System Development**
#    - **Description:** Create a user-friendly navigation system including an intuitive menu structure for easy access to all pages.
#    - **Deliverable:** Navigation system implemented in the website.
#    - **Duration:** 1 week
#    - **Dependencies:** UI Development
#
# 4. **About Us Page Design**
#    - **Description:** Design a dedicated page that highlights the company's history, values, and mission statement.
#    - **Deliverable:** Completed “About Us” page.
#    - **Duration:** 1 week
#    - **Dependencies:** None
#
# 5. **Services Page Design**
#    - **Description:** Design a services page that showcases the business's offerings along with detailed descriptions.
#    - **Deliverable:** Completed “Services” page.
#    - **Duration:** 1 week
#    - **Dependencies:** None
#
# 6. **Contact Us Page Implementation**
#    - **Description:** Create a “Contact Us” page that includes a contact form and integrated Google Map for location visibility.
#    - **Deliverable:** Functioning “Contact Us” page.
#    - **Duration:** 1 week
#    - **Dependencies:** UI Development
#
# 7. **Blog Section Development**
#    - **Description:** Implement a blog section to allow sharing of industry-related news and updates from the company.
#    - **Deliverable:** Functional blog section.
#    - **Duration:** 2 weeks
#    - **Dependencies:** UI Development
#
# 8. **Performance Optimization (SEO & Loading Times)**
#    - **Description:** Ensure the website's structure and content are optimized for fast loading and effective search engine performance.
#    - **Deliverable:** SEO-optimized website with quick loading functionality.
#    - **Duration:** 2 weeks
#    - **Dependencies:** Completion of the full website
#
# 9. **Social Media Integration**
#    - **Description:** Integrate social media buttons and sharing capabilities across the website pages.
#    - **Deliverable:** Social media functionalities on all relevant pages.
#    - **Duration:** 1 week
#    - **Dependencies:** UI Development
#
# 10. **Testimonials Section Design**
#     - **Description:** Create a section on the website to display customer testimonials to build trust and credibility.
#     - **Deliverable:** Testimonial section implemented.
#     - **Duration:** 1 week
#     - **Dependencies:** None
#
# 11. **Quality Assurance & Testing**
#     - **Description:** Conduct thorough testing of all website functionalities, including cross-device compatibility, performance, and bug fixes.
#     - **Deliverable:** QA report and final adjustments made.
#     - **Duration:** 2 weeks
#     - **Dependencies:** Completion of all content development tasks
#
# 12. **Deployment**
#     - **Description:** Launch the final version of the website on the designated hosting platform.
#     - **Deliverable:** Live website accessible to the public.
#     - **Duration:** 1 week
#     - **Dependencies:** Completion of QA & Testing
#
# ---
#
# ### Timeline Visualization (Gantt Chart):
#
# ```
# | Task                                   | Duration   | Start Date   | End Date     |
# |----------------------------------------|------------|--------------|--------------|
# | Responsive Design Creation              | 2 weeks    | Week 1       | Week 2       |
# | User Interface Development              | 2 weeks    | Week 3       | Week 4       |
# | Navigation System Development           | 1 week     | Week 5       | Week 5       |
# | About Us Page Design                   | 1 week     | Week 6       | Week 6       |
# | Services Page Design                   | 1 week     | Week 6       | Week 6       |
# | Contact Us Page Implementation         | 1 week     | Week 7       | Week 7       |
# | Blog Section Development                | 2 weeks    | Week 8       | Week 9       |
# | Performance Optimization (SEO & Speed) | 2 weeks    | Week 10      | Week 11      |
# | Social Media Integration               | 1 week     | Week 12      | Week 12      |
# | Testimonials Section Design            | 1 week     | Week 12      | Week 12      |
# | Quality Assurance & Testing            | 2 weeks    | Week 13      | Week 14      |
# | Deployment                             | 1 week     | Week 15      | Week 15      |
# ```
#
# ---
#
# ### Additional Notes:
# - Ensure effective communication between team members through regular meetings.
# - Allocate buffer times in the schedule for contingencies.
# - Utilize project management software for tracking progress and assignments.
#
# The above tasks, timelines, and deliverables ensure a comprehensive approach to successfully executing the website project for a small business, while aligning with best practices in project management.
#
#
# # Agent: Expert Estimation Analyst
# ## Task: Thoroughly evaluate each task in the Website project to estimate the time, resources, and effort required. Use historical data, task complexity, and available resources to provide a realistic estimation for each task.
#
#
#
# # Agent: Expert Estimation Analyst
# ## Final Answer:
# ### Website Project Estimation Report
#
# #### Project Title: Create a Website for a Small Business
#
# ---
#
# ### Task Breakdown and Estimations:
#
# **1. Responsive Design Creation**
# - **Description:** Develop a design that adapts seamlessly to different screen sizes.
# - **Deliverable:** A responsive design prototype.
# - **Duration:** 2 weeks
# - **Resources Required:** Bob Smith (Designer), 10 design tools/licenses.
# - **Effort Estimate:** ~80 hours.
# - **Dependencies:** None.
# - **Risks:** High variability in client feedback may lead to redesign, extending the timeline.
#
# **2. User Interface Development**
# - **Description:** Implement a modern, visually appealing user interface.
# - **Deliverable:** Finalized UI elements.
# - **Duration:** 2 weeks
# - **Resources Required:** Jane Doe (Software Engineer), 5 frontend development tools.
# - **Effort Estimate:** ~80 hours.
# - **Dependencies:** Completion of Responsive Design Creation.
# - **Risks:** Potential technical difficulties with implementation of designs could impact timelines.
#
# **3. Navigation System Development**
# - **Description:** Create a user-friendly navigation system.
# - **Deliverable:** Navigation system implemented in the website.
# - **Duration:** 1 week
# - **Resources Required:** Jane Doe (Software Engineer).
# - **Effort Estimate:** ~40 hours.
# - **Dependencies:** UI Development.
# - **Risks:** Usability issues may require iterations that extend the timeline.
#
# **4. About Us Page Design**
# - **Description:** Design a dedicated page highlighting the company's history, values, and mission.
# - **Deliverable:** Completed "About Us" page.
# - **Duration:** 1 week
# - **Resources Required:** Bob Smith (Designer).
# - **Effort Estimate:** ~20 hours.
# - **Dependencies:** None.
# - **Risks:** Misalignment with brand expectations could necessitate revisions.
#
# **5. Services Page Design**
# - **Description:** Design a services page showcasing offerings.
# - **Deliverable:** Completed "Services" page.
# - **Duration:** 1 week
# - **Resources Required:** Bob Smith (Designer).
# - **Effort Estimate:** ~20 hours.
# - **Dependencies:** None.
# - **Risks:** Client dissatisfaction with initial drafts could require additional time.
#
# **6. Contact Us Page Implementation**
# - **Description:** Create a "Contact Us" page with a form and Google Map.
# - **Deliverable:** Functioning "Contact Us" page.
# - **Duration:** 1 week
# - **Resources Required:** Jane Doe (Software Engineer).
# - **Effort Estimate:** ~30 hours.
# - **Dependencies:** UI Development.
# - **Risks:** Integration challenges with Google API may arise, potentially delaying delivery.
#
# **7. Blog Section Development**
# - **Description:** Implement a blog section for sharing updates.
# - **Deliverable:** Functional blog section.
# - **Duration:** 2 weeks
# - **Resources Required:** Jane Doe (Software Engineer).
# - **Effort Estimate:** ~80 hours.
# - **Dependencies:** UI Development.
# - **Risks:** Content management system setup may be complex, leading to delays.
#
# **8. Performance Optimization (SEO & Loading Times)**
# - **Description:** Optimize the website for speed and SEO.
# - **Deliverable:** SEO-optimized website.
# - **Duration:** 2 weeks
# - **Resources Required:** Jane Doe (Software Engineer).
# - **Effort Estimate:** ~80 hours.
# - **Dependencies:** Completion of the full website.
# - **Risks:** Potential bottlenecks in site loading speeds may require extensive testing and adjustments.
#
# **9. Social Media Integration**
# - **Description:** Integrate social media functionalities.
# - **Deliverable:** Social media capabilities on relevant pages.
# - **Duration:** 1 week
# - **Resources Required:** Jane Doe (Software Engineer).
# - **Effort Estimate:** ~30 hours.
# - **Dependencies:** UI Development.
# - **Risks:** Compatibility issues with different social media APIs.
#
# **10. Testimonials Section Design**
# - **Description:** Create a testimonials section for displaying customer feedback.
# - **Deliverable:** Testimonial section implemented.
# - **Duration:** 1 week
# - **Resources Required:** Bob Smith (Designer).
# - **Effort Estimate:** ~20 hours.
# - **Dependencies:** None.
# - **Risks:** Client revision requests could require additional design work.
#
# **11. Quality Assurance & Testing**
# - **Description:** Conduct thorough testing of all functionalities.
# - **Deliverable:** QA report with adjustments made.
# - **Duration:** 2 weeks
# - **Resources Required:** Alice Johnson (QA Engineer), Tom Brown (QA Engineer).
# - **Effort Estimate:** ~80 hours.
# - **Dependencies:** Completion of all content development tasks.
# - **Risks:** Identifying critical bugs could extend the timeline significantly.
#
# **12. Deployment**
# - **Description:** Launch the final website version.
# - **Deliverable:** Live website accessible to the public.
# - **Duration:** 1 week
# - **Resources Required:** John Doe (Project Manager), Jane Doe (Software Engineer).
# - **Effort Estimate:** ~10 hours.
# - **Dependencies:** Completion of QA & Testing.
# - **Risks:** Server or hosting issues could delay the launch if not properly planned.
#
# ---
#
# ### Summary of Risks and Uncertainties:
# - **Client Feedback:** Timelines may extend due to multiple rounds of revisions based on client feedback, particularly for design-related tasks.
# - **Technical Integration:** Challenges implementing third-party APIs or unexpected technical difficulties may alter schedules.
# - **Project Scope Adjustments:** Changes to project scope can introduce unforeseen work that impacts deadlines and resource allocations.
# - **Cross-Browser Compatibility:** Ensuring that the website operates seamlessly across different browsers and devices may require additional testing time.
#
# ---
#
# This detailed estimation report ensures a comprehensive approach to the Website project execution, aligning resources, timelines, and risk management to deliver a successful end product.
#
#
# # Agent: Resource Allocation Strategist
# ## Task: Strategically allocate tasks for the Website project to team members based on their skills, availability, and current workload. Ensure that each task is assigned to the most suitable team member and that the workload is evenly distributed.
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: Resource Allocation Strategist
# ## Final Answer:
# ### Resource Allocation Chart for Website Project
#
# | Task                           | Team Member         | Start Date  | End Date    | Estimated Hours |
# |--------------------------------|---------------------|-------------|-------------|------------------|
# | 1. Responsive Design Creation   | Bob Smith (Designer) | 01-Nov-2023 | 14-Nov-2023 | 80               |
# | 2. User Interface Development    | Jane Doe (Software Engineer) | 15-Nov-2023 | 28-Nov-2023 | 80               |
# | 3. Navigation System Development  | Jane Doe (Software Engineer) | 29-Nov-2023 | 05-Dec-2023 | 40               |
# | 4. About Us Page Design         | Bob Smith (Designer) | 01-Nov-2023 | 07-Nov-2023 | 20               |
# | 5. Services Page Design         | Bob Smith (Designer) | 08-Nov-2023 | 14-Nov-2023 | 20               |
# | 6. Contact Us Page Implementation| Jane Doe (Software Engineer) | 29-Nov-2023 | 05-Dec-2023 | 30               |
# | 7. Blog Section Development      | Jane Doe (Software Engineer) | 06-Dec-2023 | 19-Dec-2023 | 80               |
# | 8. Performance Optimization      | Jane Doe (Software Engineer) | 20-Dec-2023 | 02-Jan-2024 | 80               |
# | 9. Social Media Integration      | Jane Doe (Software Engineer) | 29-Nov-2023 | 05-Dec-2023 | 30               |
# | 10. Testimonials Section Design   | Bob Smith (Designer) | 15-Nov-2023 | 21-Nov-2023 | 20               |
# | 11. Quality Assurance & Testing  | Alice Johnson (QA Engineer), Tom Brown (QA Engineer) | 03-Jan-2024 | 16-Jan-2024 | 80               |
# | 12. Deployment                   | John Doe (Project Manager), Jane Doe (Software Engineer) | 17-Jan-2024 | 23-Jan-2024 | 10               |
#
# ### Rationale for Allocations
#
# 1. **Bob Smith (Designer)** is allocated to the **Responsive Design Creation**, **About Us Page Design**, **Services Page Design**, and **Testimonials Section Design** tasks. These tasks are design-intensive, aligning well with Bob's expertise. The workload is structured to allow for a start on the bigger responsive design task first, which is crucial for subsequent UI development.
#
# 2. **Jane Doe (Software Engineer)** takes the lead on the **User Interface Development**, **Navigation System Development**, **Contact Us Page Implementation**, **Blog Section Development**, **Performance Optimization**, and **Social Media Integration** tasks. This consolidation of software engineering tasks minimizes context switching and ensures a deeper focus as she is familiar with the design philosophy established by Bob and can integrate it directly into the UI.
#
# 3. **Alice Johnson** and **Tom Brown (QA Engineers)** are both assigned to the **Quality Assurance & Testing** phase, where thorough testing of the entire website is necessary. Their combined efforts will ensure a thorough check of all functionalities, which is crucial to address any bugs prior to deployment.
#
# 4. **John Doe (Project Manager)** is responsible for **Deployment**, overseeing the final stages and ensuring that everything aligns for a successful launch. His prior experience will help mitigate any risks associated with server issues during launch.
#
# ### Conclusion
#
# The allocations have been made to ensure an even distribution of tasks while leveraging individual strengths and maintaining workload balance. This strategic allocation enhances the efficiency of the project team, reduces the likelihood of burnout, and maximizes the potential for a successful project outcome. Each task is appropriately aligned with available expertise, enhancing the overall workflow and project timeline adherence.

# %% [markdown]
# ## Usage Metrics and Costs

# %% [markdown]
# Let’s see how much it would cost each time if this crew runs at scale.

# %%
import pandas as pd

costs = 0.150 * (crew.usage_metrics.prompt_tokens + crew.usage_metrics.completion_tokens) / 1_000_000
print(f"Total costs: ${costs:.4f}")

# Convert UsageMetrics instance to a DataFrame
df_usage_metrics = pd.DataFrame([crew.usage_metrics.dict()])
df_usage_metrics
# Out:
# Total costs: $0.0027
#    total_tokens  prompt_tokens  completion_tokens  successful_requests
# 0         18321          11217               7104                    9

# %% [markdown]
# ## Result

# %%
result.pydantic.dict()
# Out:
# {'tasks': [{'task_name': 'Responsive Design Creation',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Bob Smith (Designer)']},
#   {'task_name': 'User Interface Development',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Jane Doe (Software Engineer)']},
#   {'task_name': 'Navigation System Development',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe (Software Engineer)']},
#   {'task_name': 'About Us Page Design',
#    'estimated_time_hours': 20.0,
#    'required_resources': ['Bob Smith (Designer)']},
#   {'task_name': 'Services Page Design',
#    'estimated_time_hours': 20.0,
#    'required_resources': ['Bob Smith (Designer)']},
#   {'task_name': 'Contact Us Page Implementation',
#    'estimated_time_hours': 30.0,
#    'required_resources': ['Jane Doe (Software Engineer)']},
#   {'task_name': 'Blog Section Development',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Jane Doe (Software Engineer)']},
#   {'task_name': 'Performance Optimization',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Jane Doe (Software Engineer)']},
#   {'task_name': 'Social Media Integration',
#    'estimated_time_hours': 30.0,
#    'required_resources': ['Jane Doe (Software Engineer)']},
#   {'task_name': 'Testimonials Section Design',
#    'estimated_time_hours': 20.0,
#    'required_resources': ['Bob Smith (Designer)']},
#   {'task_name': 'Quality Assurance & Testing',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Alice Johnson (QA Engineer)',
#     'Tom Brown (QA Engineer)']},
#   {'task_name': 'Deployment',
#    'estimated_time_hours': 10.0,
#    'required_resources': ['John Doe (Project Manager)',
#     'Jane Doe (Software Engineer)']}],
#  'milestones': [{'milestone_name': 'Design Phase Completion',
#    'tasks': ['1', '4', '5', '10']},
#   {'milestone_name': 'Development Phase Completion',
#    'tasks': ['2', '3', '6', '7', '8', '9']},
#   {'milestone_name': 'Testing Phase Completion', 'tasks': ['11']},
#   {'milestone_name': 'Deployment', 'tasks': ['12']}]}

# %% [markdown]
# ## Inspect further

# %%
tasks = result.pydantic.dict()['tasks']
df_tasks = pd.DataFrame(tasks)

# Display the DataFrame as an HTML table
df_tasks.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_1ed93 th {
#   font-size: 120%;
# }
# #T_1ed93  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_1ed93" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1ed93_level0_col0" class="col_heading level0 col0" >task_name</th>
#       <th id="T_1ed93_level0_col1" class="col_heading level0 col1" >estimated_time_hours</th>
#       <th id="T_1ed93_level0_col2" class="col_heading level0 col2" >required_resources</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1ed93_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1ed93_row0_col0" class="data row0 col0" >Responsive Design Creation</td>
#       <td id="T_1ed93_row0_col1" class="data row0 col1" >80.000000</td>
#       <td id="T_1ed93_row0_col2" class="data row0 col2" >['Bob Smith (Designer)']</td>
#     </tr>
#     <tr>
#       <th id="T_1ed93_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1ed93_row1_col0" class="data row1 col0" >User Interface Development</td>
#       <td id="T_1ed93_row1_col1" class="data row1 col1" >80.000000</td>
#       <td id="T_1ed93_row1_col2" class="data row1 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_1ed93_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1ed93_row2_col0" class="data row2 col0" >Navigation System Development</td>
#       <td id="T_1ed93_row2_col1" class="data row2 col1" >40.000000</td>
#       <td id="T_1ed93_row2_col2" class="data row2 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_1ed93_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1ed93_row3_col0" class="data row3 col0" >About Us Page Design</td>
#       <td id="T_1ed93_row3_col1" class="data row3 col1" >20.000000</td>
#       <td id="T_1ed93_row3_col2" class="data row3 col2" >['Bob Smith (Designer)']</td>
#     </tr>
#     <tr>
#       <th id="T_1ed93_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1ed93_row4_col0" class="data row4 col0" >Services Page Design</td>
#       <td id="T_1ed93_row4_col1" class="data row4 col1" >20.000000</td>
#       <td id="T_1ed93_row4_col2" class="data row4 col2" >['Bob Smith (Designer)']</td>
#     </tr>
#     <tr>
#       <th id="T_1ed93_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1ed93_row5_col0" class="data row5 col0" >Contact Us Page Implementation</td>
#       <td id="T_1ed93_row5_col1" class="data row5 col1" >30.000000</td>
#       <td id="T_1ed93_row5_col2" class="data row5 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_1ed93_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1ed93_row6_col0" class="data row6 col0" >Blog Section Development</td>
#       <td id="T_1ed93_row6_col1" class="data row6 col1" >80.000000</td>
#       <td id="T_1ed93_row6_col2" class="data row6 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_1ed93_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1ed93_row7_col0" class="data row7 col0" >Performance Optimization</td>
#       <td id="T_1ed93_row7_col1" class="data row7 col1" >80.000000</td>
#       <td id="T_1ed93_row7_col2" class="data row7 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_1ed93_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1ed93_row8_col0" class="data row8 col0" >Social Media Integration</td>
#       <td id="T_1ed93_row8_col1" class="data row8 col1" >30.000000</td>
#       <td id="T_1ed93_row8_col2" class="data row8 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_1ed93_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1ed93_row9_col0" class="data row9 col0" >Testimonials Section Design</td>
#       <td id="T_1ed93_row9_col1" class="data row9 col1" >20.000000</td>
#       <td id="T_1ed93_row9_col2" class="data row9 col2" >['Bob Smith (Designer)']</td>
#     </tr>
#     <tr>
#       <th id="T_1ed93_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_1ed93_row10_col0" class="data row10 col0" >Quality Assurance & Testing</td>
#       <td id="T_1ed93_row10_col1" class="data row10 col1" >80.000000</td>
#       <td id="T_1ed93_row10_col2" class="data row10 col2" >['Alice Johnson (QA Engineer)', 'Tom Brown (QA Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_1ed93_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_1ed93_row11_col0" class="data row11 col0" >Deployment</td>
#       <td id="T_1ed93_row11_col1" class="data row11 col1" >10.000000</td>
#       <td id="T_1ed93_row11_col2" class="data row11 col2" >['John Doe (Project Manager)', 'Jane Doe (Software Engineer)']</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Inspecting Milestones

# %%
milestones = result.pydantic.dict()['milestones']
df_milestones = pd.DataFrame(milestones)

# Display the DataFrame as an HTML table
df_milestones.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_84cac th {
#   font-size: 120%;
# }
# #T_84cac  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_84cac" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_84cac_level0_col0" class="col_heading level0 col0" >milestone_name</th>
#       <th id="T_84cac_level0_col1" class="col_heading level0 col1" >tasks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_84cac_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_84cac_row0_col0" class="data row0 col0" >Design Phase Completion</td>
#       <td id="T_84cac_row0_col1" class="data row0 col1" >['1', '4', '5', '10']</td>
#     </tr>
#     <tr>
#       <th id="T_84cac_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_84cac_row1_col0" class="data row1 col0" >Development Phase Completion</td>
#       <td id="T_84cac_row1_col1" class="data row1 col1" >['2', '3', '6', '7', '8', '9']</td>
#     </tr>
#     <tr>
#       <th id="T_84cac_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_84cac_row2_col0" class="data row2 col0" >Testing Phase Completion</td>
#       <td id="T_84cac_row2_col1" class="data row2 col1" >['11']</td>
#     </tr>
#     <tr>
#       <th id="T_84cac_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_84cac_row3_col0" class="data row3 col0" >Deployment</td>
#       <td id="T_84cac_row3_col1" class="data row3 col1" >['12']</td>
#     </tr>
#   </tbody>
# </table>
