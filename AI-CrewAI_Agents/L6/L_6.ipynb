# %% [markdown]
# # L6: Building Your Crew for Production

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>

# %% [markdown]
# ## Creating a new project

# %%
! crewai create crew new_project --provider openai
# Out:
# Creating folder new_project...
#   - Created new_project/.gitignore
#   - Created new_project/pyproject.toml
#   - Created new_project/README.md
#   - Created new_project/src/new_project/__init__.py
#   - Created new_project/src/new_project/main.py
#   - Created new_project/src/new_project/crew.py
#   - Created new_project/src/new_project/tools/custom_tool.py
#   - Created new_project/src/new_project/tools/__init__.py
#   - Created new_project/src/new_project/config/agents.yaml
#   - Created new_project/src/new_project/config/tasks.yaml
# Crew new_project created successfully!

# %% [markdown]
# ## Setting up the Environment

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note</code>:</b> The following line might take a few minutes to finish.</p>

# %%
! cd new_project && crewai install
# Out:
# Using CPython 3.11.9 interpreter at: /usr/local/bin/python
# Creating virtual environment at: .venv
# Resolved 179 packages in 1.69s
# Building new-project @ file:///home/jovyan/work/L13/new_project
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/174)
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/174)
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/174)
# pygments   ------------------------------     0 B/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/174)
# ipython    ------------------------------     0 B/812.37 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/174)
# ipython    ------------------------------     0 B/812.37 KiB
# tiktoken   ------------------------------     0 B/1.10 MiB
# pygments   ------------------------------     0 B/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/174)
# pyyaml     ------------------------------     0 B/787.73 KiB
# ipython    ------------------------------     0 B/812.37 KiB
# tiktoken   ------------------------------     0 B/1.10 MiB
# pygments   ------------------------------     0 B/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/174)
# regex      ------------------------------     0 B/781.68 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# ipython    ------------------------------     0 B/812.37 KiB
# tiktoken   ------------------------------     0 B/1.10 MiB
# pygments   ------------------------------     0 B/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/174)
# huggingface-hub ------------------------------     0 B/492.03 KiB
# regex      ------------------------------     0 B/781.68 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# ipython    ------------------------------     0 B/812.37 KiB
# tiktoken   ------------------------------     0 B/1.10 MiB
# pygments   ------------------------------     0 B/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/174)
# distlib    ------------------------------     0 B/458.05 KiB
# huggingface-hub ------------------------------     0 B/492.03 KiB
# regex      ------------------------------     0 B/781.68 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# ipython    ------------------------------     0 B/812.37 KiB
# tiktoken   ------------------------------     0 B/1.10 MiB
# pygments   ------------------------------     0 B/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/174)
# pydantic   ------------------------------     0 B/451.59 KiB
# distlib    ------------------------------     0 B/458.05 KiB
# huggingface-hub ------------------------------     0 B/492.03 KiB
# regex      ------------------------------     0 B/781.68 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# ipython    ------------------------------     0 B/812.37 KiB
# tiktoken   ------------------------------     0 B/1.10 MiB
# pygments   ------------------------------     0 B/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/174)
# protobuf   ------------------------------     0 B/315.60 KiB
# pydantic   ------------------------------     0 B/451.59 KiB
# distlib    ------------------------------     0 B/458.05 KiB
# huggingface-hub ------------------------------     0 B/492.03 KiB
# regex      ------------------------------     0 B/781.68 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# ipython    ------------------------------     0 B/812.37 KiB
# tiktoken   ------------------------------     0 B/1.10 MiB
# pygments   ------------------------------     0 B/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/174)
# protobuf   ------------------------------     0 B/315.60 KiB
# prompt-toolkit ------------------------------     0 B/382.26 KiB
# pydantic   ------------------------------     0 B/451.59 KiB
# distlib    ------------------------------     0 B/458.05 KiB
# huggingface-hub ------------------------------     0 B/492.03 KiB
# regex      ------------------------------     0 B/781.68 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# ipython    ------------------------------     0 B/812.37 KiB
# tiktoken   ------------------------------     0 B/1.10 MiB
# pygments   ------------------------------     0 B/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/174)
# protobuf   ------------------------------     0 B/315.60 KiB
# rpds-py    ------------------------------     0 B/373.89 KiB
# prompt-toolkit ------------------------------     0 B/382.26 KiB
# pydantic   ------------------------------     0 B/451.59 KiB
# distlib    ------------------------------     0 B/458.05 KiB
# huggingface-hub ------------------------------     0 B/492.03 KiB
# regex      ------------------------------     0 B/781.68 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# ipython    ------------------------------     0 B/812.37 KiB
# tiktoken   ------------------------------     0 B/1.10 MiB
# pygments   ------------------------------     0 B/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/174)
# googleapis-common-protos ------------------------------     0 B/287.67 KiB
# protobuf   ------------------------------     0 B/315.60 KiB
# rpds-py    ------------------------------     0 B/373.89 KiB
# prompt-toolkit ------------------------------     0 B/382.26 KiB
# pydantic   ------------------------------     0 B/451.59 KiB
# distlib    ------------------------------     0 B/458.05 KiB
# huggingface-hub ------------------------------     0 B/492.03 KiB
# regex      ------------------------------     0 B/781.68 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# ipython    ------------------------------     0 B/812.37 KiB
# tiktoken   ------------------------------     0 B/1.10 MiB
# pygments   ------------------------------     0 B/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/174)
# googleapis-common-protos ------------------------------     0 B/287.67 KiB
# protobuf   ------------------------------     0 B/315.60 KiB
# rpds-py    ------------------------------     0 B/373.89 KiB
# prompt-toolkit ------------------------------     0 B/382.26 KiB
# pydantic   ------------------------------     0 B/451.59 KiB
# distlib    ------------------------------     0 B/458.05 KiB
# huggingface-hub ------------------------------     0 B/492.03 KiB
# regex      ------------------------------     0 B/781.68 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# ipython    ------------------------------     0 B/812.37 KiB
# tiktoken   ------------------------------     0 B/1.10 MiB
# pygments   ------------------------------     0 B/1.17 MiB
# pydantic-core ------------------------------ 14.91 KiB/1.98 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/174)
# googleapis-common-protos ------------------------------     0 B/287.67 KiB
# protobuf   ------------------------------     0 B/315.60 KiB
# rpds-py    ------------------------------     0 B/373.89 KiB
# prompt-toolkit ------------------------------     0 B/382.26 KiB
# pydantic   ------------------------------     0 B/451.59 KiB
# distlib    ------------------------------     0 B/458.05 KiB
# huggingface-hub ------------------------------     0 B/492.03 KiB
# regex      ------------------------------     0 B/781.68 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# ipython    ------------------------------     0 B/812.37 KiB
# tiktoken   ------------------------------     0 B/1.10 MiB
# pygments   ------------------------------ 14.88 KiB/1.17 MiB
# pydantic-core ------------------------------ 14.91 KiB/1.98 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/174)
# googleapis-common-protos ------------------------------ 30.87 KiB/287.67 KiB
# protobuf   ------------------------------ 30.85 KiB/315.60 KiB
# pypdf      ------------------------------ 16.00 KiB/316.27 KiB
# jiter      ------------------------------ 30.92 KiB/343.92 KiB
# anthropic  ------------------------------ 31.24 KiB/349.09 KiB
# yarl       ------------------------------ 30.92 KiB/357.25 KiB
# rpds-py    ------------------------------ 30.92 KiB/373.89 KiB
# prompt-toolkit ------------------------------ 30.88 KiB/382.26 KiB
# watchfiles ------------------------------ 46.81 KiB/445.39 KiB
# pydantic   ------------------------------ 14.88 KiB/451.59 KiB
# distlib    ------------------------------ 46.88 KiB/458.05 KiB
# crewai     ------------------------------ 16.00 KiB/462.12 KiB
# huggingface-hub ------------------------------ 46.88 KiB/492.03 KiB
# mpmath     ------------------------------ 46.85 KiB/523.63 KiB
# greenlet   ------------------------------ 16.00 KiB/573.91 KiB
# crewai-tools ------------------------------ 16.00 KiB/723.68 KiB
# pyvis      ------------------------------ 14.84 KiB/738.32 KiB
# regex      ------------------------------ 62.91 KiB/781.68 KiB
# pyyaml     ------------------------------ 62.68 KiB/787.73 KiB
# ipython    ------------------------------ 62.88 KiB/812.37 KiB
# openai     ------------------------------ 36.86 KiB/926.39 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/174)
# googleapis-common-protos ------------------------------ 30.87 KiB/287.67 KiB
# protobuf   ------------------------------ 75.21 KiB/315.60 KiB
# pypdf      ------------------------------ 32.00 KiB/316.27 KiB
# jiter      ------------------------------ 78.92 KiB/343.92 KiB
# anthropic  ------------------------------ 31.24 KiB/349.09 KiB
# yarl       ------------------------------ 69.03 KiB/357.25 KiB
# rpds-py    ------------------------------ 76.87 KiB/373.89 KiB
# prompt-toolkit ------------------------------ 30.88 KiB/382.26 KiB
# watchfiles ------------------------------ 75.20 KiB/445.39 KiB
# pydantic   ------------------------------ 30.88 KiB/451.59 KiB
# distlib    ------------------------------ 62.88 KiB/458.05 KiB
# crewai     ------------------------------ 16.00 KiB/462.12 KiB
# youtube-transcript-api ------------------------------ 14.87 KiB/473.77 KiB
# huggingface-hub ------------------------------ 46.88 KiB/492.03 KiB
# mpmath     ------------------------------ 78.46 KiB/523.63 KiB
# greenlet   ------------------------------ 16.00 KiB/573.91 KiB
# crewai-tools ------------------------------ 16.00 KiB/723.68 KiB
# pyvis      ------------------------------ 14.84 KiB/738.32 KiB
# regex      ------------------------------ 75.70 KiB/781.68 KiB
# pyyaml     ------------------------------ 75.76 KiB/787.73 KiB
# ipython    ------------------------------ 62.88 KiB/812.37 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/174)
# googleapis-common-protos ------------------------------ 30.87 KiB/287.67 KiB
# protobuf   ------------------------------ 75.21 KiB/315.60 KiB
# pypdf      ------------------------------ 32.00 KiB/316.27 KiB
# jiter      ------------------------------ 78.92 KiB/343.92 KiB
# anthropic  ------------------------------ 31.24 KiB/349.09 KiB
# yarl       ------------------------------ 69.03 KiB/357.25 KiB
# rpds-py    ------------------------------ 76.87 KiB/373.89 KiB
# prompt-toolkit ------------------------------ 30.88 KiB/382.26 KiB
# watchfiles ------------------------------ 75.20 KiB/445.39 KiB
# pydantic   ------------------------------ 30.88 KiB/451.59 KiB
# distlib    ------------------------------ 62.88 KiB/458.05 KiB
# crewai     ------------------------------ 32.00 KiB/462.12 KiB
# youtube-transcript-api ------------------------------ 14.87 KiB/473.77 KiB
# huggingface-hub ------------------------------ 46.88 KiB/492.03 KiB
# mpmath     ------------------------------ 78.46 KiB/523.63 KiB
# greenlet   ------------------------------ 16.00 KiB/573.91 KiB
# crewai-tools ------------------------------ 16.00 KiB/723.68 KiB
# pyvis      ------------------------------ 14.84 KiB/738.32 KiB
# regex      ------------------------------ 75.70 KiB/781.68 KiB
# pyyaml     ------------------------------ 75.76 KiB/787.73 KiB
# ipython    ------------------------------ 62.88 KiB/812.37 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/174)
# googleapis-common-protos ------------------------------ 46.87 KiB/287.67 KiB
# protobuf   ------------------------------ 155.21 KiB/315.60 KiB
# pypdf      ------------------------------ 79.02 KiB/316.27 KiB
# jiter      ------------------------------ 174.92 KiB/343.92 KiB
# anthropic  ------------------------------ 47.24 KiB/349.09 KiB
# yarl       ------------------------------ 140.02 KiB/357.25 KiB
# rpds-py    ------------------------------ 185.97 KiB/373.89 KiB
# prompt-toolkit ------------------------------ 46.88 KiB/382.26 KiB
# watchfiles ------------------------------ 187.20 KiB/445.39 KiB
# httptools  ------------------------------ 13.92 KiB/445.92 KiB
# pydantic   ------------------------------ 46.88 KiB/451.59 KiB
# distlib    ------------------------------ 156.27 KiB/458.05 KiB
# crewai     ------------------------------ 48.00 KiB/462.12 KiB
# youtube-transcript-api ------------------------------ 14.87 KiB/473.77 KiB
# huggingface-hub ------------------------------ 77.82 KiB/492.03 KiB
# mpmath     ------------------------------ 142.46 KiB/523.63 KiB
# greenlet   ------------------------------ 48.00 KiB/573.91 KiB
# crewai-tools ------------------------------ 16.00 KiB/723.68 KiB
# pyvis      ------------------------------ 46.84 KiB/738.32 KiB
# regex      ------------------------------ 171.70 KiB/781.68 KiB
# pyyaml     ------------------------------ 170.68 KiB/787.73 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/174)
# googleapis-common-protos ------------------------------ 62.87 KiB/287.67 KiB
# protobuf   ------------------------------ 203.21 KiB/315.60 KiB
# pypdf      ------------------------------ 143.02 KiB/316.27 KiB
# jiter      ------------------------------ 254.92 KiB/343.92 KiB
# anthropic  ------------------------------ 61.79 KiB/349.09 KiB
# yarl       ------------------------------ 236.02 KiB/357.25 KiB
# rpds-py    ------------------------------ 252.87 KiB/373.89 KiB
# prompt-toolkit ------------------------------ 78.53 KiB/382.26 KiB
# watchfiles ------------------------------ 249.44 KiB/445.39 KiB
# httptools  ------------------------------ 125.92 KiB/445.92 KiB
# pydantic   ------------------------------ 139.38 KiB/451.59 KiB
# distlib    ------------------------------ 236.17 KiB/458.05 KiB
# crewai     ------------------------------ 64.00 KiB/462.12 KiB
# youtube-transcript-api ------------------------------ 195.15 KiB/473.77 KiB
# huggingface-hub ------------------------------ 205.82 KiB/492.03 KiB
# mpmath     ------------------------------ 206.46 KiB/523.63 KiB
# greenlet   ------------------------------ 252.68 KiB/573.91 KiB
# crewai-tools ------------------------------ 31.89 KiB/723.68 KiB
# pyvis      ------------------------------ 254.84 KiB/738.32 KiB
# regex      ------------------------------ 235.70 KiB/781.68 KiB
# pyyaml     ------------------------------ 235.76 KiB/787.73 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/174)
# googleapis-common-protos ------------------------------ 91.35 KiB/287.67 KiB
# protobuf   ------------------------------ 255.21 KiB/315.60 KiB
# pypdf      ------------------------------ 255.02 KiB/316.27 KiB
# jiter      ------------------------------ 334.92 KiB/343.92 KiB
# anthropic  ------------------------------ 77.79 KiB/349.09 KiB
# yarl       ------------------------------ 310.75 KiB/357.25 KiB
# rpds-py    ------------------------------ 316.87 KiB/373.89 KiB
# prompt-toolkit ------------------------------ 103.34 KiB/382.26 KiB
# watchfiles ------------------------------ 319.20 KiB/445.39 KiB
# httptools  ------------------------------ 173.92 KiB/445.92 KiB
# pydantic   ------------------------------ 187.38 KiB/451.59 KiB
# distlib    ------------------------------ 286.72 KiB/458.05 KiB
# crewai     ------------------------------ 80.00 KiB/462.12 KiB
# youtube-transcript-api ------------------------------ 270.77 KiB/473.77 KiB
# huggingface-hub ------------------------------ 285.82 KiB/492.03 KiB
# mpmath     ------------------------------ 302.46 KiB/523.63 KiB
# greenlet   ------------------------------ 316.56 KiB/573.91 KiB
# crewai-tools ------------------------------ 47.79 KiB/723.68 KiB
# pyvis      ------------------------------ 334.84 KiB/738.32 KiB
# regex      ------------------------------ 303.70 KiB/781.68 KiB
# pyyaml     ------------------------------ 303.76 KiB/787.73 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/174)
# googleapis-common-protos ------------------------------ 91.35 KiB/287.67 KiB
# protobuf   ------------------------------ 255.21 KiB/315.60 KiB
# pypdf      ------------------------------ 271.02 KiB/316.27 KiB
# anthropic  ------------------------------ 77.79 KiB/349.09 KiB
# yarl       ------------------------------ 326.75 KiB/357.25 KiB
# rpds-py    ------------------------------ 332.87 KiB/373.89 KiB
# prompt-toolkit ------------------------------ 103.34 KiB/382.26 KiB
# watchfiles ------------------------------ 335.20 KiB/445.39 KiB
# httptools  ------------------------------ 205.92 KiB/445.92 KiB
# pydantic   ------------------------------ 203.38 KiB/451.59 KiB
# distlib    ------------------------------ 316.27 KiB/458.05 KiB
# crewai     ------------------------------ 80.00 KiB/462.12 KiB
# youtube-transcript-api ------------------------------ 275.20 KiB/473.77 KiB
# huggingface-hub ------------------------------ 317.82 KiB/492.03 KiB
# mpmath     ------------------------------ 350.46 KiB/523.63 KiB
# greenlet   ------------------------------ 316.78 KiB/573.91 KiB
# crewai-tools ------------------------------ 47.79 KiB/723.68 KiB
# pyvis      ------------------------------ 350.84 KiB/738.32 KiB
# regex      ------------------------------ 335.70 KiB/781.68 KiB
# pyyaml     ------------------------------ 335.76 KiB/787.73 KiB
# ipython    ------------------------------ 270.78 KiB/812.37 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/174)
# bcrypt     ------------------------------     0 B/271.72 KiB
# googleapis-common-protos ------------------------------ 107.35 KiB/287.67 KiB
# protobuf   ------------------------------ 287.21 KiB/315.60 KiB
# pypdf      ------------------------------ 302.59 KiB/316.27 KiB
# anthropic  ------------------------------ 93.79 KiB/349.09 KiB
# yarl       ------------------------------ 357.25 KiB/357.25 KiB
# prompt-toolkit ------------------------------ 119.34 KiB/382.26 KiB
# watchfiles ------------------------------ 399.20 KiB/445.39 KiB
# httptools  ------------------------------ 253.92 KiB/445.92 KiB
# pydantic   ------------------------------ 271.38 KiB/451.59 KiB
# distlib    ------------------------------ 364.27 KiB/458.05 KiB
# crewai     ------------------------------ 112.00 KiB/462.12 KiB
# youtube-transcript-api ------------------------------ 323.20 KiB/473.77 KiB
# huggingface-hub ------------------------------ 333.71 KiB/492.03 KiB
# mpmath     ------------------------------ 414.46 KiB/523.63 KiB
# greenlet   ------------------------------ 379.67 KiB/573.91 KiB
# crewai-tools ------------------------------ 64.00 KiB/723.68 KiB
# pyvis      ------------------------------ 391.23 KiB/738.32 KiB
# regex      ------------------------------ 375.13 KiB/781.68 KiB
# pyyaml     ------------------------------ 383.76 KiB/787.73 KiB
# ipython    ------------------------------ 334.78 KiB/812.37 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/174)
# bcrypt     ------------------------------ 16.00 KiB/271.72 KiB
# googleapis-common-protos ------------------------------ 107.35 KiB/287.67 KiB
# protobuf   ------------------------------ 303.10 KiB/315.60 KiB
# pypdf      ------------------------------ 302.59 KiB/316.27 KiB
# anthropic  ------------------------------ 93.79 KiB/349.09 KiB
# yarl       ------------------------------ 357.25 KiB/357.25 KiB
# prompt-toolkit ------------------------------ 119.34 KiB/382.26 KiB
# watchfiles ------------------------------ 415.20 KiB/445.39 KiB
# httptools  ------------------------------ 269.92 KiB/445.92 KiB
# pydantic   ------------------------------ 271.38 KiB/451.59 KiB
# distlib    ------------------------------ 380.27 KiB/458.05 KiB
# crewai     ------------------------------ 112.00 KiB/462.12 KiB
# youtube-transcript-api ------------------------------ 334.87 KiB/473.77 KiB
# huggingface-hub ------------------------------ 333.71 KiB/492.03 KiB
# mpmath     ------------------------------ 414.46 KiB/523.63 KiB
# greenlet   ------------------------------ 380.78 KiB/573.91 KiB
# crewai-tools ------------------------------ 64.00 KiB/723.68 KiB
# pyvis      ------------------------------ 398.84 KiB/738.32 KiB
# regex      ------------------------------ 383.70 KiB/781.68 KiB
# pyyaml     ------------------------------ 399.76 KiB/787.73 KiB
# ipython    ------------------------------ 334.78 KiB/812.37 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/174)
# bcrypt     ------------------------------ 32.00 KiB/271.72 KiB
# googleapis-common-protos ------------------------------ 107.35 KiB/287.67 KiB
# protobuf   ------------------------------ 315.60 KiB/315.60 KiB
# pypdf      ------------------------------ 316.27 KiB/316.27 KiB
# anthropic  ------------------------------ 93.79 KiB/349.09 KiB
# prompt-toolkit ------------------------------ 119.34 KiB/382.26 KiB
# watchfiles ------------------------------ 431.20 KiB/445.39 KiB
# httptools  ------------------------------ 285.92 KiB/445.92 KiB
# pydantic   ------------------------------ 287.38 KiB/451.59 KiB
# distlib    ------------------------------ 396.27 KiB/458.05 KiB
# crewai     ------------------------------ 112.00 KiB/462.12 KiB
# youtube-transcript-api ------------------------------ 350.87 KiB/473.77 KiB
# huggingface-hub ------------------------------ 333.71 KiB/492.03 KiB
# mpmath     ------------------------------ 414.46 KiB/523.63 KiB
# greenlet   ------------------------------ 396.78 KiB/573.91 KiB
# crewai-tools ------------------------------ 64.00 KiB/723.68 KiB
# pyvis      ------------------------------ 414.84 KiB/738.32 KiB
# regex      ------------------------------ 399.70 KiB/781.68 KiB
# pyyaml     ------------------------------ 415.66 KiB/787.73 KiB
# ipython    ------------------------------ 352.99 KiB/812.37 KiB
# openai     ------------------------------ 94.78 KiB/926.39 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/174)
# python-docx ------------------------------ 16.00 KiB/247.06 KiB
# bcrypt     ------------------------------ 63.66 KiB/271.72 KiB
# googleapis-common-protos ------------------------------ 123.35 KiB/287.67 KiB
# protobuf   ------------------------------ 315.60 KiB/315.60 KiB
# pypdf      ------------------------------ 316.27 KiB/316.27 KiB
# anthropic  ------------------------------ 93.79 KiB/349.09 KiB
# prompt-toolkit ------------------------------ 135.34 KiB/382.26 KiB
# httptools  ------------------------------ 301.92 KiB/445.92 KiB
# pydantic   ------------------------------ 287.38 KiB/451.59 KiB
# distlib    ------------------------------ 428.17 KiB/458.05 KiB
# crewai     ------------------------------ 112.00 KiB/462.12 KiB
# youtube-transcript-api ------------------------------ 366.87 KiB/473.77 KiB
# huggingface-hub ------------------------------ 333.71 KiB/492.03 KiB
# mpmath     ------------------------------ 414.46 KiB/523.63 KiB
# greenlet   ------------------------------ 412.78 KiB/573.91 KiB
# crewai-tools ------------------------------ 64.00 KiB/723.68 KiB
# pyvis      ------------------------------ 430.84 KiB/738.32 KiB
# regex      ------------------------------ 405.22 KiB/781.68 KiB
# pyyaml     ------------------------------ 447.66 KiB/787.73 KiB
# ipython    ------------------------------ 352.99 KiB/812.37 KiB
# openai     ------------------------------ 94.78 KiB/926.39 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/174)
# python-docx ------------------------------ 16.00 KiB/247.06 KiB
# bcrypt     ------------------------------ 79.66 KiB/271.72 KiB
# googleapis-common-protos ------------------------------ 123.35 KiB/287.67 KiB
# protobuf   ------------------------------ 315.60 KiB/315.60 KiB
# anthropic  ------------------------------ 109.79 KiB/349.09 KiB
# prompt-toolkit ------------------------------ 135.34 KiB/382.26 KiB
# httptools  ------------------------------ 301.92 KiB/445.92 KiB
# pydantic   ------------------------------ 303.38 KiB/451.59 KiB
# distlib    ------------------------------ 428.17 KiB/458.05 KiB
# crewai     ------------------------------ 112.00 KiB/462.12 KiB
# youtube-transcript-api ------------------------------ 382.87 KiB/473.77 KiB
# huggingface-hub ------------------------------ 333.71 KiB/492.03 KiB
# mpmath     ------------------------------ 420.67 KiB/523.63 KiB
# greenlet   ------------------------------ 428.78 KiB/573.91 KiB
# crewai-tools ------------------------------ 80.00 KiB/723.68 KiB
# pyvis      ------------------------------ 446.84 KiB/738.32 KiB
# regex      ------------------------------ 421.22 KiB/781.68 KiB
# pyyaml     ------------------------------ 447.66 KiB/787.73 KiB
# ipython    ------------------------------ 352.99 KiB/812.37 KiB
# openai     ------------------------------ 94.78 KiB/926.39 KiB
# tiktoken   ------------------------------ 453.39 KiB/1.10 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (5/174)
# rich       ------------------------------     0 B/237.69 KiB
# multidict  ------------------------------ 14.91 KiB/240.93 KiB
# openpyxl   ------------------------------ 14.88 KiB/245.03 KiB
# python-docx ------------------------------ 32.00 KiB/247.06 KiB
# bcrypt     ------------------------------ 111.66 KiB/271.72 KiB
# googleapis-common-protos ------------------------------ 139.35 KiB/287.67 KiB
# protobuf   ------------------------------ 315.60 KiB/315.60 KiB
# anthropic  ------------------------------ 125.79 KiB/349.09 KiB
# prompt-toolkit ------------------------------ 142.53 KiB/382.26 KiB
# httptools  ------------------------------ 365.92 KiB/445.92 KiB
# pydantic   ------------------------------ 303.38 KiB/451.59 KiB
# distlib    ------------------------------ 458.05 KiB/458.05 KiB
# crewai     ------------------------------ 128.00 KiB/462.12 KiB
# youtube-transcript-api ------------------------------ 424.56 KiB/473.77 KiB
# huggingface-hub ------------------------------ 349.71 KiB/492.03 KiB
# mpmath     ------------------------------ 494.46 KiB/523.63 KiB
# greenlet   ------------------------------ 444.78 KiB/573.91 KiB
# crewai-tools ------------------------------ 80.00 KiB/723.68 KiB
# pyvis      ------------------------------ 486.13 KiB/738.32 KiB
# regex      ------------------------------ 439.02 KiB/781.68 KiB
# pyyaml     ------------------------------ 479.76 KiB/787.73 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (5/174)
# rich       ------------------------------ 30.89 KiB/237.69 KiB
# multidict  ------------------------------ 30.91 KiB/240.93 KiB
# openpyxl   ------------------------------ 14.88 KiB/245.03 KiB
# python-docx ------------------------------ 32.00 KiB/247.06 KiB
# bcrypt     ------------------------------ 127.66 KiB/271.72 KiB
# googleapis-common-protos ------------------------------ 139.35 KiB/287.67 KiB
# protobuf   ------------------------------ 315.60 KiB/315.60 KiB
# anthropic  ------------------------------ 125.79 KiB/349.09 KiB
# prompt-toolkit ------------------------------ 158.53 KiB/382.26 KiB
# httptools  ------------------------------ 381.92 KiB/445.92 KiB
# pydantic   ------------------------------ 319.38 KiB/451.59 KiB
# crewai     ------------------------------ 128.00 KiB/462.12 KiB
# youtube-transcript-api ------------------------------ 440.56 KiB/473.77 KiB
# huggingface-hub ------------------------------ 349.71 KiB/492.03 KiB
# mpmath     ------------------------------ 510.46 KiB/523.63 KiB
# greenlet   ------------------------------ 460.78 KiB/573.91 KiB
# crewai-tools ------------------------------ 96.00 KiB/723.68 KiB
# pyvis      ------------------------------ 502.13 KiB/738.32 KiB
# regex      ------------------------------ 447.70 KiB/781.68 KiB
# pyyaml     ------------------------------ 495.76 KiB/787.73 KiB
# ipython    ------------------------------ 382.78 KiB/812.37 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (5/174)
# google-genai ------------------------------ 16.00 KiB/237.21 KiB
# rich       ------------------------------ 46.89 KiB/237.69 KiB
# multidict  ------------------------------ 93.08 KiB/240.93 KiB
# openpyxl   ------------------------------ 30.88 KiB/245.03 KiB
# python-docx ------------------------------ 48.00 KiB/247.06 KiB
# bcrypt     ------------------------------ 191.66 KiB/271.72 KiB
# googleapis-common-protos ------------------------------ 155.35 KiB/287.67 KiB
# protobuf   ------------------------------ 315.60 KiB/315.60 KiB
# anthropic  ------------------------------ 157.79 KiB/349.09 KiB
# prompt-toolkit ------------------------------ 190.53 KiB/382.26 KiB
# httptools  ------------------------------ 445.92 KiB/445.92 KiB
# pydantic   ------------------------------ 363.45 KiB/451.59 KiB
# crewai     ------------------------------ 128.00 KiB/462.12 KiB
# huggingface-hub ------------------------------ 373.47 KiB/492.03 KiB
# mpmath     ------------------------------ 523.63 KiB/523.63 KiB
# greenlet   ------------------------------ 476.78 KiB/573.91 KiB
# crewai-tools ------------------------------ 112.00 KiB/723.68 KiB
# pyvis      ------------------------------ 565.76 KiB/738.32 KiB
# regex      ------------------------------ 543.70 KiB/781.68 KiB
# pyyaml     ------------------------------ 575.76 KiB/787.73 KiB
# ipython    ------------------------------ 414.78 KiB/812.37 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (5/174)
# google-genai ------------------------------ 32.00 KiB/237.21 KiB
# rich       ------------------------------ 46.89 KiB/237.69 KiB
# multidict  ------------------------------ 93.08 KiB/240.93 KiB
# openpyxl   ------------------------------ 30.88 KiB/245.03 KiB
# python-docx ------------------------------ 48.00 KiB/247.06 KiB
# bcrypt     ------------------------------ 191.66 KiB/271.72 KiB
# googleapis-common-protos ------------------------------ 155.35 KiB/287.67 KiB
# protobuf   ------------------------------ 315.60 KiB/315.60 KiB
# anthropic  ------------------------------ 157.79 KiB/349.09 KiB
# prompt-toolkit ------------------------------ 190.53 KiB/382.26 KiB
# httptools  ------------------------------ 445.92 KiB/445.92 KiB
# pydantic   ------------------------------ 363.45 KiB/451.59 KiB
# crewai     ------------------------------ 128.00 KiB/462.12 KiB
# huggingface-hub ------------------------------ 373.47 KiB/492.03 KiB
# greenlet   ------------------------------ 476.78 KiB/573.91 KiB
# crewai-tools ------------------------------ 112.00 KiB/723.68 KiB
# pyvis      ------------------------------ 565.76 KiB/738.32 KiB
# regex      ------------------------------ 543.70 KiB/781.68 KiB
# pyyaml     ------------------------------ 575.76 KiB/787.73 KiB
# ipython    ------------------------------ 414.78 KiB/812.37 KiB
# openai     ------------------------------ 158.89 KiB/926.39 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (5/174)
# google-genai ------------------------------ 32.00 KiB/237.21 KiB
# rich       ------------------------------ 62.78 KiB/237.69 KiB
# multidict  ------------------------------ 94.15 KiB/240.93 KiB
# openpyxl   ------------------------------ 30.88 KiB/245.03 KiB
# python-docx ------------------------------ 63.53 KiB/247.06 KiB
# bcrypt     ------------------------------ 207.66 KiB/271.72 KiB
# googleapis-common-protos ------------------------------ 155.35 KiB/287.67 KiB
# protobuf   ------------------------------ 315.60 KiB/315.60 KiB
# anthropic  ------------------------------ 157.79 KiB/349.09 KiB
# prompt-toolkit ------------------------------ 190.53 KiB/382.26 KiB
# httptools  ------------------------------ 445.92 KiB/445.92 KiB
# pydantic   ------------------------------ 399.38 KiB/451.59 KiB
# crewai     ------------------------------ 128.00 KiB/462.12 KiB
# huggingface-hub ------------------------------ 373.47 KiB/492.03 KiB
# greenlet   ------------------------------ 476.78 KiB/573.91 KiB
# crewai-tools ------------------------------ 112.00 KiB/723.68 KiB
# pyvis      ------------------------------ 581.76 KiB/738.32 KiB
# regex      ------------------------------ 543.70 KiB/781.68 KiB
# pyyaml     ------------------------------ 591.76 KiB/787.73 KiB
# ipython    ------------------------------ 430.78 KiB/812.37 KiB
# openai     ------------------------------ 158.89 KiB/926.39 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (5/174)
# frozenlist ------------------------------     0 B/225.65 KiB
# google-genai ------------------------------ 48.00 KiB/237.21 KiB
# rich       ------------------------------ 62.78 KiB/237.69 KiB
# multidict  ------------------------------ 110.15 KiB/240.93 KiB
# openpyxl   ------------------------------ 30.88 KiB/245.03 KiB
# python-docx ------------------------------ 63.53 KiB/247.06 KiB
# bcrypt     ------------------------------ 223.66 KiB/271.72 KiB
# googleapis-common-protos ------------------------------ 171.35 KiB/287.67 KiB
# protobuf   ------------------------------ 315.60 KiB/315.60 KiB
# anthropic  ------------------------------ 157.79 KiB/349.09 KiB
# prompt-toolkit ------------------------------ 206.53 KiB/382.26 KiB
# pydantic   ------------------------------ 415.38 KiB/451.59 KiB
# crewai     ------------------------------ 128.00 KiB/462.12 KiB
# huggingface-hub ------------------------------ 373.47 KiB/492.03 KiB
# greenlet   ------------------------------ 476.78 KiB/573.91 KiB
# crewai-tools ------------------------------ 112.00 KiB/723.68 KiB
# pyvis      ------------------------------ 590.84 KiB/738.32 KiB
# regex      ------------------------------ 559.70 KiB/781.68 KiB
# pyyaml     ------------------------------ 607.76 KiB/787.73 KiB
# ipython    ------------------------------ 446.67 KiB/812.37 KiB
# openai     ------------------------------ 174.89 KiB/926.39 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (5/174)
# python-dateutil ------------------------------     0 B/224.50 KiB
# frozenlist ------------------------------ 16.00 KiB/225.65 KiB
# tomli      ------------------------------ 30.92 KiB/236.38 KiB
# google-genai ------------------------------ 76.74 KiB/237.21 KiB
# rich       ------------------------------ 109.41 KiB/237.69 KiB
# multidict  ------------------------------ 141.08 KiB/240.93 KiB
# openpyxl   ------------------------------ 46.88 KiB/245.03 KiB
# python-docx ------------------------------ 79.53 KiB/247.06 KiB
# bcrypt     ------------------------------ 255.66 KiB/271.72 KiB
# googleapis-common-protos ------------------------------ 187.35 KiB/287.67 KiB
# protobuf   ------------------------------ 315.60 KiB/315.60 KiB
# anthropic  ------------------------------ 157.79 KiB/349.09 KiB
# prompt-toolkit ------------------------------ 254.53 KiB/382.26 KiB
# crewai     ------------------------------ 144.00 KiB/462.12 KiB
# huggingface-hub ------------------------------ 397.82 KiB/492.03 KiB
# greenlet   ------------------------------ 492.78 KiB/573.91 KiB
# crewai-tools ------------------------------ 128.00 KiB/723.68 KiB
# pyvis      ------------------------------ 622.84 KiB/738.32 KiB
# regex      ------------------------------ 578.38 KiB/781.68 KiB
# pyyaml     ------------------------------ 639.76 KiB/787.73 KiB
# ipython    ------------------------------ 462.78 KiB/812.37 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (5/174)
# lance-namespace-urllib3-client ------------------------------ 16.00 KiB/224.25 KiB
# python-dateutil ------------------------------ 30.87 KiB/224.50 KiB
# frozenlist ------------------------------ 48.00 KiB/225.65 KiB
# tomli      ------------------------------ 62.92 KiB/236.38 KiB
# google-genai ------------------------------ 108.74 KiB/237.21 KiB
# rich       ------------------------------ 125.41 KiB/237.69 KiB
# multidict  ------------------------------ 173.08 KiB/240.93 KiB
# openpyxl   ------------------------------ 46.88 KiB/245.03 KiB
# python-docx ------------------------------ 96.67 KiB/247.06 KiB
# googleapis-common-protos ------------------------------ 203.35 KiB/287.67 KiB
# protobuf   ------------------------------ 315.60 KiB/315.60 KiB
# anthropic  ------------------------------ 157.79 KiB/349.09 KiB
# prompt-toolkit ------------------------------ 283.50 KiB/382.26 KiB
# crewai     ------------------------------ 144.00 KiB/462.12 KiB
# huggingface-hub ------------------------------ 429.82 KiB/492.03 KiB
# greenlet   ------------------------------ 525.97 KiB/573.91 KiB
# crewai-tools ------------------------------ 144.00 KiB/723.68 KiB
# pyvis      ------------------------------ 654.84 KiB/738.32 KiB
# regex      ------------------------------ 610.38 KiB/781.68 KiB
# pyyaml     ------------------------------ 671.76 KiB/787.73 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (5/174)
# lance-namespace-urllib3-client ------------------------------ 16.00 KiB/224.25 KiB
# python-dateutil ------------------------------ 30.87 KiB/224.50 KiB
# frozenlist ------------------------------ 62.58 KiB/225.65 KiB
# tomli      ------------------------------ 62.92 KiB/236.38 KiB
# google-genai ------------------------------ 124.74 KiB/237.21 KiB
# rich       ------------------------------ 125.41 KiB/237.69 KiB
# multidict  ------------------------------ 189.08 KiB/240.93 KiB
# openpyxl   ------------------------------ 46.88 KiB/245.03 KiB
# python-docx ------------------------------ 96.67 KiB/247.06 KiB
# googleapis-common-protos ------------------------------ 203.35 KiB/287.67 KiB
# anthropic  ------------------------------ 169.55 KiB/349.09 KiB
# prompt-toolkit ------------------------------ 299.30 KiB/382.26 KiB
# crewai     ------------------------------ 144.00 KiB/462.12 KiB
# huggingface-hub ------------------------------ 429.82 KiB/492.03 KiB
# greenlet   ------------------------------ 541.97 KiB/573.91 KiB
# crewai-tools ------------------------------ 144.00 KiB/723.68 KiB
# pyvis      ------------------------------ 654.84 KiB/738.32 KiB
# regex      ------------------------------ 626.38 KiB/781.68 KiB
# pyyaml     ------------------------------ 687.76 KiB/787.73 KiB
# ipython    ------------------------------ 478.85 KiB/812.37 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (5/174)
# lance-namespace-urllib3-client ------------------------------ 16.00 KiB/224.25 KiB
# python-dateutil ------------------------------ 46.87 KiB/224.50 KiB
# frozenlist ------------------------------ 62.58 KiB/225.65 KiB
# tomli      ------------------------------ 78.81 KiB/236.38 KiB
# google-genai ------------------------------ 124.74 KiB/237.21 KiB
# rich       ------------------------------ 125.41 KiB/237.69 KiB
# multidict  ------------------------------ 189.08 KiB/240.93 KiB
# openpyxl   ------------------------------ 46.88 KiB/245.03 KiB
# python-docx ------------------------------ 96.67 KiB/247.06 KiB
# googleapis-common-protos ------------------------------ 203.35 KiB/287.67 KiB
# anthropic  ------------------------------ 169.55 KiB/349.09 KiB
# prompt-toolkit ------------------------------ 299.30 KiB/382.26 KiB
# crewai     ------------------------------ 144.00 KiB/462.12 KiB
# huggingface-hub ------------------------------ 445.82 KiB/492.03 KiB
# greenlet   ------------------------------ 541.97 KiB/573.91 KiB
# crewai-tools ------------------------------ 144.00 KiB/723.68 KiB
# pyvis      ------------------------------ 670.84 KiB/738.32 KiB
# regex      ------------------------------ 626.38 KiB/781.68 KiB
# pyyaml     ------------------------------ 687.76 KiB/787.73 KiB
# ipython    ------------------------------ 478.85 KiB/812.37 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (5/174)
# pre-commit ------------------------------ 14.91 KiB/215.79 KiB
# google-auth ------------------------------ 62.88 KiB/217.33 KiB
# lance-namespace-urllib3-client ------------------------------ 80.00 KiB/224.25 KiB
# python-dateutil ------------------------------ 126.64 KiB/224.50 KiB
# frozenlist ------------------------------ 142.58 KiB/225.65 KiB
# tomli      ------------------------------ 142.92 KiB/236.38 KiB
# google-genai ------------------------------ 204.74 KiB/237.21 KiB
# rich       ------------------------------ 205.41 KiB/237.69 KiB
# openpyxl   ------------------------------ 78.33 KiB/245.03 KiB
# python-docx ------------------------------ 143.53 KiB/247.06 KiB
# googleapis-common-protos ------------------------------ 235.35 KiB/287.67 KiB
# anthropic  ------------------------------ 185.55 KiB/349.09 KiB
# prompt-toolkit ------------------------------ 367.94 KiB/382.26 KiB
# crewai     ------------------------------ 175.89 KiB/462.12 KiB
# huggingface-hub ------------------------------ 477.82 KiB/492.03 KiB
# greenlet   ------------------------------ 572.78 KiB/573.91 KiB
# crewai-tools ------------------------------ 160.00 KiB/723.68 KiB
# pyvis      ------------------------------ 734.84 KiB/738.32 KiB
# regex      ------------------------------ 717.48 KiB/781.68 KiB
# pyyaml     ------------------------------ 767.76 KiB/787.73 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (5/174)
# pre-commit ------------------------------ 14.91 KiB/215.79 KiB
# google-auth ------------------------------ 62.88 KiB/217.33 KiB
# lance-namespace-urllib3-client ------------------------------ 96.00 KiB/224.25 KiB
# python-dateutil ------------------------------ 126.64 KiB/224.50 KiB
# frozenlist ------------------------------ 142.58 KiB/225.65 KiB
# tomli      ------------------------------ 142.92 KiB/236.38 KiB
# google-genai ------------------------------ 204.74 KiB/237.21 KiB
# rich       ------------------------------ 205.41 KiB/237.69 KiB
# openpyxl   ------------------------------ 78.33 KiB/245.03 KiB
# python-docx ------------------------------ 143.53 KiB/247.06 KiB
# googleapis-common-protos ------------------------------ 235.35 KiB/287.67 KiB
# anthropic  ------------------------------ 185.55 KiB/349.09 KiB
# prompt-toolkit ------------------------------ 367.94 KiB/382.26 KiB
# crewai     ------------------------------ 175.89 KiB/462.12 KiB
# huggingface-hub ------------------------------ 477.82 KiB/492.03 KiB
# crewai-tools ------------------------------ 160.00 KiB/723.68 KiB
# pyvis      ------------------------------ 734.84 KiB/738.32 KiB
# regex      ------------------------------ 717.48 KiB/781.68 KiB
# pyyaml     ------------------------------ 767.76 KiB/787.73 KiB
# ipython    ------------------------------ 578.79 KiB/812.37 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (5/174)
# pre-commit ------------------------------ 30.91 KiB/215.79 KiB
# google-auth ------------------------------ 62.88 KiB/217.33 KiB
# lance-namespace-urllib3-client ------------------------------ 96.00 KiB/224.25 KiB
# python-dateutil ------------------------------ 126.64 KiB/224.50 KiB
# frozenlist ------------------------------ 142.58 KiB/225.65 KiB
# tomli      ------------------------------ 142.92 KiB/236.38 KiB
# google-genai ------------------------------ 204.74 KiB/237.21 KiB
# rich       ------------------------------ 205.41 KiB/237.69 KiB
# openpyxl   ------------------------------ 78.33 KiB/245.03 KiB
# python-docx ------------------------------ 143.53 KiB/247.06 KiB
# googleapis-common-protos ------------------------------ 235.35 KiB/287.67 KiB
# anthropic  ------------------------------ 185.55 KiB/349.09 KiB
# prompt-toolkit ------------------------------ 367.94 KiB/382.26 KiB
# crewai     ------------------------------ 175.89 KiB/462.12 KiB
# crewai-tools ------------------------------ 160.00 KiB/723.68 KiB
# pyvis      ------------------------------ 738.32 KiB/738.32 KiB
# regex      ------------------------------ 717.48 KiB/781.68 KiB
# pyyaml     ------------------------------ 783.76 KiB/787.73 KiB
# ipython    ------------------------------ 578.79 KiB/812.37 KiB
# openai     ------------------------------ 270.89 KiB/926.39 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (5/174)
# pre-commit ------------------------------ 30.91 KiB/215.79 KiB
# google-auth ------------------------------ 62.88 KiB/217.33 KiB
# lance-namespace-urllib3-client ------------------------------ 96.00 KiB/224.25 KiB
# python-dateutil ------------------------------ 126.64 KiB/224.50 KiB
# frozenlist ------------------------------ 142.58 KiB/225.65 KiB
# tomli      ------------------------------ 142.92 KiB/236.38 KiB
# google-genai ------------------------------ 204.74 KiB/237.21 KiB
# rich       ------------------------------ 205.41 KiB/237.69 KiB
# openpyxl   ------------------------------ 78.33 KiB/245.03 KiB
# python-docx ------------------------------ 143.53 KiB/247.06 KiB
# googleapis-common-protos ------------------------------ 235.35 KiB/287.67 KiB
# anthropic  ------------------------------ 185.55 KiB/349.09 KiB
# prompt-toolkit ------------------------------ 367.94 KiB/382.26 KiB
# crewai     ------------------------------ 175.89 KiB/462.12 KiB
# crewai-tools ------------------------------ 160.00 KiB/723.68 KiB
# regex      ------------------------------ 717.48 KiB/781.68 KiB
# pyyaml     ------------------------------ 783.76 KiB/787.73 KiB
# ipython    ------------------------------ 594.79 KiB/812.37 KiB
# openai     ------------------------------ 270.89 KiB/926.39 KiB
# tiktoken   ------------------------------ 763.83 KiB/1.10 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (5/174)
# pre-commit ------------------------------ 30.91 KiB/215.79 KiB
# google-auth ------------------------------ 62.88 KiB/217.33 KiB
# lance-namespace-urllib3-client ------------------------------ 96.00 KiB/224.25 KiB
# python-dateutil ------------------------------ 142.74 KiB/224.50 KiB
# frozenlist ------------------------------ 142.58 KiB/225.65 KiB
# tomli      ------------------------------ 158.92 KiB/236.38 KiB
# google-genai ------------------------------ 204.74 KiB/237.21 KiB
# rich       ------------------------------ 223.21 KiB/237.69 KiB
# openpyxl   ------------------------------ 78.33 KiB/245.03 KiB
# python-docx ------------------------------ 143.53 KiB/247.06 KiB
# googleapis-common-protos ------------------------------ 235.35 KiB/287.67 KiB
# anthropic  ------------------------------ 185.55 KiB/349.09 KiB
# prompt-toolkit ------------------------------ 367.94 KiB/382.26 KiB
# crewai     ------------------------------ 191.79 KiB/462.12 KiB
# crewai-tools ------------------------------ 160.00 KiB/723.68 KiB
# regex      ------------------------------ 717.48 KiB/781.68 KiB
# pyyaml     ------------------------------ 783.76 KiB/787.73 KiB
# ipython    ------------------------------ 594.79 KiB/812.37 KiB
# openai     ------------------------------ 270.89 KiB/926.39 KiB
# tiktoken   ------------------------------ 763.83 KiB/1.10 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (5/174)
# fsspec     ------------------------------     0 B/196.26 KiB
# opentelemetry-semantic-conventions ------------------------------     0 B/203.08 KiB
# propcache  ------------------------------ 14.88 KiB/205.11 KiB
# cffi       ------------------------------   973 B/210.52 KiB
# pre-commit ------------------------------ 30.91 KiB/215.79 KiB
# ...
# ⠦ Preparing packages... (168/174) 25.39 MiB/46.38 MiB
# jedi       ------------------------------ 1.22 MiB/1.50 MiB
# onnxruntime ------------------------------ 15.91 MiB/16.57 MiB
# lancedb    ------------------------------ 24.48 MiB/36.92 MiB
# playwright ------------------------------ 24.62 MiB/43.78 MiB
# pyarrow    ------------------------------ 23.48 MiB/45.49 MiB
# ⠦ Preparing packages... (168/174) 26.20 MiB/46.38 MiB
# jedi       ------------------------------ 1.22 MiB/1.50 MiB
# onnxruntime ------------------------------ 15.91 MiB/16.57 MiB
# lancedb    ------------------------------ 24.48 MiB/36.92 MiB
# playwright ------------------------------ 24.62 MiB/43.78 MiB
# pyarrow    ------------------------------ 23.59 MiB/45.49 MiB
# ⠦ Preparing packages... (168/174) 26.20 MiB/46.38 MiB
# jedi       ------------------------------ 1.22 MiB/1.50 MiB
# onnxruntime ------------------------------ 15.91 MiB/16.57 MiB
# lancedb    ------------------------------ 24.48 MiB/36.92 MiB
# playwright ------------------------------ 24.62 MiB/43.78 MiB
# pyarrow    ------------------------------ 25.72 MiB/45.49 MiB
# ⠦ Preparing packages... (168/174) 26.45 MiB/46.38 MiB
# jedi       ------------------------------ 1.22 MiB/1.50 MiB
# onnxruntime ------------------------------ 15.91 MiB/16.57 MiB
# lancedb    ------------------------------ 24.48 MiB/36.92 MiB
# playwright ------------------------------ 25.10 MiB/43.78 MiB
# pyarrow    ------------------------------ 25.72 MiB/45.49 MiB
# ⠦ Preparing packages... (168/174) 26.45 MiB/46.38 MiB
# jedi       ------------------------------ 1.22 MiB/1.50 MiB
# onnxruntime ------------------------------ 15.92 MiB/16.57 MiB
# lancedb    ------------------------------ 24.95 MiB/36.92 MiB
# playwright ------------------------------ 27.61 MiB/43.78 MiB
# pyarrow    ------------------------------ 26.28 MiB/45.49 MiB
# ⠧ Preparing packages... (168/174) 27.73 MiB/46.38 MiB
# jedi       ------------------------------ 1.22 MiB/1.50 MiB
# onnxruntime ------------------------------ 15.92 MiB/16.57 MiB
# lancedb    ------------------------------ 24.95 MiB/36.92 MiB
# playwright ------------------------------ 27.61 MiB/43.78 MiB
# pyarrow    ------------------------------ 26.37 MiB/45.49 MiB
# ⠧ Preparing packages... (168/174) 27.73 MiB/46.38 MiB
# jedi       ------------------------------ 1.24 MiB/1.50 MiB
# onnxruntime ------------------------------ 15.92 MiB/16.57 MiB
# lancedb    ------------------------------ 24.95 MiB/36.92 MiB
# playwright ------------------------------ 27.61 MiB/43.78 MiB
# pyarrow    ------------------------------ 26.37 MiB/45.49 MiB
# ⠧ Preparing packages... (168/174) 27.73 MiB/46.38 MiB
# jedi       ------------------------------ 1.24 MiB/1.50 MiB
# onnxruntime ------------------------------ 15.92 MiB/16.57 MiB
# lancedb    ------------------------------ 24.95 MiB/36.92 MiB
# playwright ------------------------------ 27.61 MiB/43.78 MiB
# pyarrow    ------------------------------ 26.37 MiB/45.49 MiB
# ⠧ Preparing packages... (168/174) 27.73 MiB/46.38 MiB
# onnxruntime ------------------------------ 15.92 MiB/16.57 MiB
# lancedb    ------------------------------ 24.95 MiB/36.92 MiB
# playwright ------------------------------ 27.61 MiB/43.78 MiB
# pyarrow    ------------------------------ 26.37 MiB/45.49 MiB
# ⠧ Preparing packages... (168/174) 27.73 MiB/46.38 MiB
# onnxruntime ------------------------------ 15.92 MiB/16.57 MiB
# lancedb    ------------------------------ 24.95 MiB/36.92 MiB
# playwright ------------------------------ 27.94 MiB/43.78 MiB
# pyarrow    ------------------------------ 26.50 MiB/45.49 MiB
# ⠧ Preparing packages... (168/174) 27.73 MiB/46.38 MiB
# onnxruntime ------------------------------ 15.94 MiB/16.57 MiB
# lancedb    ------------------------------ 24.95 MiB/36.92 MiB
# playwright ------------------------------ 30.50 MiB/43.78 MiB
# pyarrow    ------------------------------ 29.00 MiB/45.49 MiB
# ⠇ Preparing packages... (169/174) 27.73 MiB/46.38 MiB
# onnxruntime ------------------------------ 16.02 MiB/16.57 MiB
# lancedb    ------------------------------ 24.95 MiB/36.92 MiB
# playwright ------------------------------ 33.90 MiB/43.78 MiB
# pyarrow    ------------------------------ 30.22 MiB/45.49 MiB
# ⠇ Preparing packages... (169/174) 27.73 MiB/46.38 MiB
# onnxruntime ------------------------------ 16.02 MiB/16.57 MiB
# lancedb    ------------------------------ 25.03 MiB/36.92 MiB
# playwright ------------------------------ 34.78 MiB/43.78 MiB
# pyarrow    ------------------------------ 31.81 MiB/45.49 MiB
# ⠇ Preparing packages... (169/174) 27.73 MiB/46.38 MiB
# onnxruntime ------------------------------ 16.02 MiB/16.57 MiB
# lancedb    ------------------------------ 25.40 MiB/36.92 MiB
# playwright ------------------------------ 34.78 MiB/43.78 MiB
# pyarrow    ------------------------------ 31.81 MiB/45.49 MiB
# ⠇ Preparing packages... (169/174) 27.73 MiB/46.38 MiB
# onnxruntime ------------------------------ 16.02 MiB/16.57 MiB
# lancedb    ------------------------------ 28.23 MiB/36.92 MiB
# playwright ------------------------------ 34.78 MiB/43.78 MiB
# pyarrow    ------------------------------ 31.81 MiB/45.49 MiB
# ⠋ Preparing packages... (169/174) 29.39 MiB/46.38 MiB
# onnxruntime ------------------------------ 16.02 MiB/16.57 MiB
# lancedb    ------------------------------ 30.45 MiB/36.92 MiB
# playwright ------------------------------ 34.78 MiB/43.78 MiB
# pyarrow    ------------------------------ 31.81 MiB/45.49 MiB
# ⠋ Preparing packages... (169/174) 32.10 MiB/46.38 MiB
# onnxruntime ------------------------------ 16.11 MiB/16.57 MiB
# lancedb    ------------------------------ 30.56 MiB/36.92 MiB
# playwright ------------------------------ 34.78 MiB/43.78 MiB
# pyarrow    ------------------------------ 33.98 MiB/45.49 MiB
# ⠙ Preparing packages... (169/174) 32.12 MiB/46.38 MiB
# onnxruntime ------------------------------ 16.52 MiB/16.57 MiB
# lancedb    ------------------------------ 30.56 MiB/36.92 MiB
# playwright ------------------------------ 34.78 MiB/43.78 MiB
# pyarrow    ------------------------------ 34.90 MiB/45.49 MiB
# ⠙ Preparing packages... (169/174) 32.12 MiB/46.38 MiB
# onnxruntime ------------------------------ 16.52 MiB/16.57 MiB
# lancedb    ------------------------------ 30.56 MiB/36.92 MiB
# playwright ------------------------------ 34.78 MiB/43.78 MiB
# pyarrow    ------------------------------ 34.90 MiB/45.49 MiB
# ⠙ Preparing packages... (169/174) 32.20 MiB/46.38 MiB
# onnxruntime ------------------------------ 16.52 MiB/16.57 MiB
# lancedb    ------------------------------ 30.56 MiB/36.92 MiB
# playwright ------------------------------ 34.78 MiB/43.78 MiB
# pyarrow    ------------------------------ 34.90 MiB/45.49 MiB
# ⠙ Preparing packages... (169/174) 32.61 MiB/46.38 MiB
# onnxruntime ------------------------------ 16.52 MiB/16.57 MiB
# lancedb    ------------------------------ 32.95 MiB/36.92 MiB
# playwright ------------------------------ 34.78 MiB/43.78 MiB
# pyarrow    ------------------------------ 34.90 MiB/45.49 MiB
# ⠙ Preparing packages... (169/174) 35.40 MiB/46.38 MiB
# lancedb    ------------------------------ 33.10 MiB/36.92 MiB
# playwright ------------------------------ 34.78 MiB/43.78 MiB
# pyarrow    ------------------------------ 34.90 MiB/45.49 MiB
# ⠙ Preparing packages... (169/174) 35.81 MiB/46.38 MiB
# lancedb    ------------------------------ 33.10 MiB/36.92 MiB
# playwright ------------------------------ 34.78 MiB/43.78 MiB
# pyarrow    ------------------------------ 36.09 MiB/45.49 MiB
# ⠹ Preparing packages... (170/174) 35.81 MiB/46.38 MiB
# lancedb    ------------------------------ 33.10 MiB/36.92 MiB
# playwright ------------------------------ 37.07 MiB/43.78 MiB
# pyarrow    ------------------------------ 36.84 MiB/45.49 MiB
# ⠹ Preparing packages... (170/174) 35.81 MiB/46.38 MiB
# lancedb    ------------------------------ 33.22 MiB/36.92 MiB
# playwright ------------------------------ 37.07 MiB/43.78 MiB
# pyarrow    ------------------------------ 36.84 MiB/45.49 MiB
# ⠹ Preparing packages... (170/174) 35.81 MiB/46.38 MiB
# lancedb    ------------------------------ 33.23 MiB/36.92 MiB
# playwright ------------------------------ 37.07 MiB/43.78 MiB
# pyarrow    ------------------------------ 36.84 MiB/45.49 MiB
# ⠹ Preparing packages... (170/174) 35.81 MiB/46.38 MiB
# lancedb    ------------------------------ 35.00 MiB/36.92 MiB
# playwright ------------------------------ 37.07 MiB/43.78 MiB
# pyarrow    ------------------------------ 36.84 MiB/45.49 MiB
# ⠹ Preparing packages... (170/174) 37.51 MiB/46.38 MiB
# lancedb    ------------------------------ 36.91 MiB/36.92 MiB
# playwright ------------------------------ 37.07 MiB/43.78 MiB
# pyarrow    ------------------------------ 36.84 MiB/45.49 MiB
# ⠹ Preparing packages... (170/174) 40.00 MiB/46.38 MiB
# playwright ------------------------------ 37.07 MiB/43.78 MiB
# pyarrow    ------------------------------ 36.84 MiB/45.49 MiB
# ⠸ Preparing packages... (171/174) 40.00 MiB/46.38 MiB
# playwright ------------------------------ 37.18 MiB/43.78 MiB
# pyarrow    ------------------------------ 36.84 MiB/45.49 MiB
# ⠸ Preparing packages... (171/174) 43.42 MiB/46.38 MiB
# playwright ------------------------------ 37.19 MiB/43.78 MiB
# pyarrow    ------------------------------ 36.84 MiB/45.49 MiB
# ⠸ Preparing packages... (171/174) 43.42 MiB/46.38 MiB
# playwright ------------------------------ 41.02 MiB/43.78 MiB
# pyarrow    ------------------------------ 36.84 MiB/45.49 MiB
# ⠸ Preparing packages... (171/174) 43.42 MiB/46.38 MiB
# playwright ------------------------------ 41.17 MiB/43.78 MiB
# pyarrow    ------------------------------ 39.12 MiB/45.49 MiB
# ⠼ Preparing packages... (171/174) 43.42 MiB/46.38 MiB
# playwright ------------------------------ 41.22 MiB/43.78 MiB
# pyarrow    ------------------------------ 39.43 MiB/45.49 MiB
# ⠼ Preparing packages... (171/174) 43.42 MiB/46.38 MiB
# playwright ------------------------------ 41.23 MiB/43.78 MiB
# pyarrow    ------------------------------ 39.43 MiB/45.49 MiB
# ⠼ Preparing packages... (171/174) 43.42 MiB/46.38 MiB
# playwright ------------------------------ 41.24 MiB/43.78 MiB
# pyarrow    ------------------------------ 39.43 MiB/45.49 MiB
# ⠼ Preparing packages... (171/174) 43.42 MiB/46.38 MiB
# playwright ------------------------------ 42.55 MiB/43.78 MiB
# pyarrow    ------------------------------ 39.43 MiB/45.49 MiB
# ⠴ Preparing packages... (171/174) 43.42 MiB/46.38 MiB
# pyarrow    ------------------------------ 39.43 MiB/45.49 MiB
# ⠦ Preparing packages... (172/174) 43.42 MiB/46.38 MiB
# pyarrow    ------------------------------ 39.60 MiB/45.49 MiB
# ⠦ Preparing packages... (172/174) 43.42 MiB/46.38 MiB
# pyarrow    ------------------------------ 39.61 MiB/45.49 MiB
# ⠦ Preparing packages... (172/174) 43.42 MiB/46.38 MiB
# pyarrow    ------------------------------ 39.63 MiB/45.49 MiB
# ⠦ Preparing packages... (172/174) 43.42 MiB/46.38 MiB
# pyarrow    ------------------------------ 39.64 MiB/45.49 MiB
# ⠦ Preparing packages... (172/174) 43.42 MiB/46.38 MiB
# pyarrow    ------------------------------ 39.66 MiB/45.49 MiB
# ⠦ Preparing packages... (172/174) 43.42 MiB/46.38 MiB
# pyarrow    ------------------------------ 42.93 MiB/45.49 MiB
# ⠦ Preparing packages... (172/174) 43.96 MiB/46.38 MiB
# pyarrow    ------------------------------ 43.86 MiB/45.49 MiB
# ⠦ Preparing packages... (172/174) 46.23 MiB/46.38 MiB
# ⠦ Preparing packages... (172/174) 44.39 MiB/45.49 MiB
# Prepared 174 packages in 6.60s
# Installed 174 packages in 178ms
#  + aiohappyeyeballs==2.6.1
#  + aiohttp==3.13.2
#  + aiosignal==1.4.0
#  + annotated-types==0.7.0
#  + anthropic==0.72.0
#  + anyio==4.11.0
#  + appdirs==1.4.4
#  + asttokens==3.0.0
#  + attrs==25.4.0
#  + backoff==2.2.1
#  + bcrypt==5.0.0
#  + beautifulsoup4==4.14.2
#  + blinker==1.9.0
#  + browserbase==1.4.0
#  + build==1.3.0
#  + cachetools==6.2.1
#  + certifi==2025.10.5
#  + cffi==2.0.0
#  + cfgv==3.4.0
#  + charset-normalizer==3.4.4
#  + chromadb==1.1.1
#  + click==8.3.0
#  + coloredlogs==15.0.1
#  + crewai==0.203.1
#  + crewai-tools==0.76.0
#  + cryptography==46.0.3
#  + decorator==5.2.1
#  + defusedxml==0.7.1
#  + deprecation==2.1.0
#  + diskcache==5.6.3
#  + distlib==0.4.0
#  + distro==1.9.0
#  + docker==7.1.0
#  + docstring-parser==0.17.0
#  + durationpy==0.10
#  + et-xmlfile==2.0.0
#  + executing==2.2.1
#  + filelock==3.20.0
#  + flatbuffers==25.9.23
#  + frozenlist==1.8.0
#  + fsspec==2025.10.0
#  + google-auth==2.42.1
#  + google-genai==1.48.0
#  + googleapis-common-protos==1.71.0
#  + greenlet==3.2.4
#  + grpcio==1.76.0
#  + h11==0.16.0
#  + hf-xet==1.2.0
#  + httpcore==1.0.9
#  + httptools==0.7.1
#  + httpx==0.28.1
#  + huggingface-hub==1.0.1
#  + humanfriendly==10.0
#  + identify==2.6.15
#  + idna==3.11
#  + importlib-metadata==8.7.0
#  + importlib-resources==6.5.2
#  + instructor==1.12.0
#  + ipython==8.37.0
#  + jedi==0.19.2
#  + jinja2==3.1.6
#  + jiter==0.10.0
#  + json-repair==0.25.2
#  + json5==0.12.1
#  + jsonpickle==4.1.1
#  + jsonref==1.1.0
#  + jsonschema==4.25.1
#  + jsonschema-specifications==2025.9.1
#  + kubernetes==34.1.0
#  + lance-namespace==0.0.20
#  + lance-namespace-urllib3-client==0.0.20
#  + lancedb==0.25.2
#  + litellm==1.74.9
#  + lxml==6.0.2
#  + markdown-it-py==4.0.0
#  + markupsafe==3.0.3
#  + matplotlib-inline==0.2.1
#  + mdurl==0.1.2
#  + mmh3==5.2.0
#  + mpmath==1.3.0
#  + multidict==6.7.0
#  + nest-asyncio==1.6.0
#  + networkx==3.4.2
#  + new-project==0.1.0 (from file:///home/jovyan/work/L13/new_project)
#  + nodeenv==1.9.1
#  + numpy==2.2.6
#  + oauthlib==3.3.1
#  + onnxruntime==1.23.2
#  + openai==1.109.1
#  + openpyxl==3.1.5
#  + opentelemetry-api==1.38.0
#  + opentelemetry-exporter-otlp-proto-common==1.38.0
#  + opentelemetry-exporter-otlp-proto-grpc==1.38.0
#  + opentelemetry-exporter-otlp-proto-http==1.38.0
#  + opentelemetry-proto==1.38.0
#  + opentelemetry-sdk==1.38.0
#  + opentelemetry-semantic-conventions==0.59b0
#  + orjson==3.11.4
#  + overrides==7.7.0
#  + packaging==25.0
#  + parso==0.8.5
#  + pdfminer-six==20250506
#  + pdfplumber==0.11.7
#  + pexpect==4.9.0
#  + pillow==12.0.0
#  + platformdirs==4.5.0
#  + playwright==1.55.0
#  + portalocker==2.7.0
#  + posthog==5.4.0
#  + pre-commit==4.3.0
#  + prompt-toolkit==3.0.52
#  + propcache==0.4.1
#  + protobuf==6.33.0
#  + ptyprocess==0.7.0
#  + pure-eval==0.2.3
#  + pyarrow==22.0.0
#  + pyasn1==0.6.1
#  + pyasn1-modules==0.4.2
#  + pybase64==1.4.2
#  + pycparser==2.23
#  + pydantic==2.12.3
#  + pydantic-core==2.41.4
#  + pydantic-settings==2.11.0
#  + pyee==13.0.0
#  + pygments==2.19.2
#  + pyjwt==2.10.1
#  + pylance==0.39.0
#  + pypdf==6.1.3
#  + pypdfium2==5.0.0
#  + pypika==0.48.9
#  + pyproject-hooks==1.2.0
#  + python-dateutil==2.9.0.post0
#  + python-docx==1.2.0
#  + python-dotenv==1.2.1
#  + pytube==15.0.0
#  + pyvis==0.3.2
#  + pyyaml==6.0.3
#  + referencing==0.37.0
#  + regex==2025.11.3
#  + requests==2.32.5
#  + requests-oauthlib==2.0.0
#  + rich==14.2.0
#  + rpds-py==0.28.0
#  + rsa==4.9.1
#  + shellingham==1.5.4
#  + six==1.17.0
#  + sniffio==1.3.1
#  + soupsieve==2.8
#  + stack-data==0.6.3
#  + stagehand==0.5.5
#  + sympy==1.14.0
#  + tenacity==9.1.2
#  + tiktoken==0.12.0
#  + tokenizers==0.22.1
#  + tomli==2.3.0
#  + tomli-w==1.2.0
#  + tqdm==4.67.1
#  + traitlets==5.14.3
#  + typer==0.20.0
#  + typer-slim==0.20.0
#  + typing-extensions==4.15.0
#  + typing-inspection==0.4.2
#  + urllib3==2.3.0
#  + uv==0.9.7
#  + uvicorn==0.38.0
#  + uvloop==0.22.1
#  + virtualenv==20.35.4
#  + watchfiles==1.1.1
#  + wcwidth==0.2.14
#  + websocket-client==1.9.0
#  + websockets==15.0.1
#  + yarl==1.22.0
#  + youtube-transcript-api==1.2.3
#  + zipp==3.23.0

# %% [markdown]
# ## Setting Environment Variables

# %%
! cat new_project/.env
# Out:
# OPENAI_API_KEY=YOUR_API_KEY_HERE

# %% [markdown]
# ## Running the Crew

# %%
! cd new_project && crewai run
# Out:
# Running the Crew
# ╭─────────────────────────── Crew Execution Started ───────────────────────────╮
# │                                                                              │
# │  Crew Execution Started                                                      │
# │  Name: crew                                                                  │
# │  ID: 5670c234-c0ed-4501-a028-1103e70128c4                                    │
# │  Tool Args:                                                                  │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: d6b3ea19-fc51-4316-8ca2-e4dc02d61089)
#     Status: Executing Task...
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: AI LLMs Senior Data Researcher                                       │
# │                                                                              │
# │  Task: Conduct a thorough research about AI LLMs Make sure you find any      │
# │  interesting and relevant information given the current year is 2024.        │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: d6b3ea19-fc51-4316-8ca2-e4dc02d61089)
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: d6b3ea19-fc51-4316-8ca2-e4dc02d61089)
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: d6b3ea19-fc51-4316-8ca2-e4dc02d61089)
#     Status: Executing Task...
# ╭─────────────────────────── ✅ Agent Final Answer ────────────────────────────╮
# │                                                                              │
# │  Agent: AI LLMs Senior Data Researcher                                       │
# │                                                                              │
# │  Final Answer:                                                               │
# │  Here are 10 bullet points highlighting the most relevant information about  │
# │  AI LLMs as of 2024:                                                         │
# │                                                                              │
# │  1. **Increased Model Sizes**: The trend of scaling up model sizes           │
# │  continues, with new LLMs reaching upwards of several hundred billion        │
# │  parameters. These models demonstrate increased understanding and            │
# │  generation abilities, pushing the boundaries of natural language            │
# │  processing.                                                                 │
# │                                                                              │
# │  2. **Multimodal Capabilities**: AI LLMs are increasingly incorporating      │
# │  multimodal functionalities, allowing them to process and generate text,     │
# │  images, and even audio within a single model. This is exemplified by        │
# │  advancements seen in models like GPT-4 and its successors.                  │
# │                                                                              │
# │  3. **Lowering Carbon Footprint**: There is a growing emphasis on reducing   │
# │  the environmental impact of training LLMs. New energy-efficient             │
# │  architectures and training techniques are being developed to mitigate       │
# │  carbon emissions associated with model training.                            │
# │                                                                              │
# │  4. **Fine-Tuning and Customization**: Companies are investing in methods    │
# │  to easily fine-tune pre-trained LLMs for specific applications, allowing    │
# │  businesses to tailor models to their unique needs without requiring         │
# │  extensive computational resources.                                          │
# │                                                                              │
# │  5. **Focus on Ethical AI**: The AI community is increasingly prioritizing   │
# │  ethics and responsible AI development, with initiatives aimed at            │
# │  addressing biases, ensuring data transparency, and establishing guidelines  │
# │  for the deployment of AI technologies.                                      │
# │                                                                              │
# │  6. **Real-Time Interaction and Conversational AI**: 2024 has seen           │
# │  significant improvements in real-time conversational capabilities for       │
# │  LLMs, allowing for more dynamic and engaging interactions in applications   │
# │  like customer service and virtual assistants.                               │
# │                                                                              │
# │  7. **Robustness Against Adversarial Attacks**: Researchers are making       │
# │  strides in enhancing the robustness of LLMs against adversarial attacks by  │
# │  developing new training methodologies that can better withstand inputs      │
# │  designed to mislead models.                                                 │
# │                                                                              │
# │  8. **Interdisciplinary Applications**: LLMs are not limited to traditional  │
# │  language tasks; they are being applied successfully across various fields,  │
# │  including healthcare for medical documentation, legal for contract          │
# │  analysis, and finance for risk assessment.                                  │
# │                                                                              │
# │  9. **Open-Source Collaboration**: The open-source movement continues to     │
# │  thrive with communities contributing to frameworks and datasets that        │
# │  advance LLM research. Projects like Hugging Face and EleutherAI are         │
# │  pivotal in democratizing access to powerful language models.                │
# │                                                                              │
# │  10. **Regulatory Considerations**: As governments and organizations         │
# │  recognize the impact of AI technologies on society, there is a growing      │
# │  body of regulatory frameworks emerging to govern the use of LLMs,           │
# │  impacting data privacy, model transparency, and accountability.             │
# │                                                                              │
# │  These bullet points encompass the cutting-edge developments and key trends  │
# │  in the field of AI LLMs as of 2024, reflecting both technological           │
# │  advancements and societal considerations.                                   │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: d6b3ea19-fc51-4316-8ca2-e4dc02d61089)
#     Assigned to: AI LLMs Senior Data Researcher
#
#     Status: ✅ Completed
# ╭────────────────────────────── Task Completion ───────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name: research_task                                                         │
# │  Agent: AI LLMs Senior Data Researcher                                       │
# │                                                                              │
# │  Tool Args:                                                                  │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: d6b3ea19-fc51-4316-8ca2-e4dc02d61089)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 06ab6486-9b83-4294-a71b-3ee5a394e158)
#     Status: Executing Task...
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: AI LLMs Reporting Analyst                                            │
# │                                                                              │
# │  Task: Review the context you got and expand each topic into a full section  │
# │  for a report. Make sure the report is detailed and contains any and all     │
# │  relevant information.                                                       │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: d6b3ea19-fc51-4316-8ca2-e4dc02d61089)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 06ab6486-9b83-4294-a71b-3ee5a394e158)
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: d6b3ea19-fc51-4316-8ca2-e4dc02d61089)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 06ab6486-9b83-4294-a71b-3ee5a394e158)
#     Status: Executing Task...
# ╭─────────────────────────── ✅ Agent Final Answer ────────────────────────────╮
# │                                                                              │
# │  Agent: AI LLMs Reporting Analyst                                            │
# │                                                                              │
# │  Final Answer:                                                               │
# │  # Report on Current Trends in AI Large Language Models (LLMs) - 2024        │
# │                                                                              │
# │  ## 1. Increased Model Sizes                                                 │
# │  The trend towards scaling up the size of language models shows no signs of  │
# │  slowing down in 2024. Recent advancements have led to the development of    │
# │  LLMs that boast parameter counts reaching into the hundreds of billions.    │
# │  These expansive models exhibit a marked improvement in their capabilities   │
# │  for understanding context, generating coherent text, and addressing         │
# │  complex queries across various topics. The sheer size of these models       │
# │  enables them to capture intricate patterns in language, leading to          │
# │  enhanced performance in natural language processing tasks. Major players    │
# │  in the field, including OpenAI, Google, and Meta, continue to push the      │
# │  boundaries, fostering breakthroughs that contribute to more nuanced and     │
# │  contextually aware AI systems.                                              │
# │                                                                              │
# │  ## 2. Multimodal Capabilities                                               │
# │  In 2024, AI LLMs are increasingly integrating multimodal capabilities,      │
# │  demonstrating proficiency in processing and generating a variety of         │
# │  content types—text, images, and audio—within a single framework. Notable    │
# │  examples include models derived from GPT-4, which can analyze visual        │
# │  inputs and produce relevant textual descriptions or engage in dialogues     │
# │  that seamlessly incorporate graphical content. This advancement represents  │
# │  a significant step toward more holistic AI systems that can understand and  │
# │  interact with the world in a more human-like manner. The rise of            │
# │  multimodal models facilitates a broader range of applications, from         │
# │  immersive virtual experiences to enhanced assistive technologies for        │
# │  individuals with disabilities.                                              │
# │                                                                              │
# │  ## 3. Lowering Carbon Footprint                                             │
# │  As awareness of climate change intensifies, the AI community is making      │
# │  concerted efforts to address the carbon footprint associated with training  │
# │  large language models. Innovative energy-efficient architectures and        │
# │  training methodologies are being explored to minimize environmental         │
# │  impact. Research into techniques such as distillation, pruning, and         │
# │  low-rank factorization is ongoing, with a focus on reducing the             │
# │  computational resources required for effective model training.              │
# │  Additionally, collaborations with organizations dedicated to                │
# │  sustainability aim to optimize data center operations and promote the use   │
# │  of renewable energy sources in AI research and deployment.                  │
# │                                                                              │
# │  ## 4. Fine-Tuning and Customization                                         │
# │  Organizations across different sectors are increasingly focused on          │
# │  fine-tuning and customizing pre-trained LLMs to meet specific operational   │
# │  needs. This trend is fueled by the understanding that tailored models can   │
# │  yield superior performance without the need for extensive computational     │
# │  power or resources. Businesses are investing in user-friendly frameworks    │
# │  that streamline the fine-tuning process, enabling even small teams to       │
# │  adapt powerful models for unique applications, such as customer support     │
# │  chatbots or specialized content generation tools. This democratization of   │
# │  technology not only enhances productivity but also allows for more diverse  │
# │  representation in the use of AI solutions.                                  │
# │                                                                              │
# │  ## 5. Focus on Ethical AI                                                   │
# │  In 2024, there is an increasing commitment to ethical AI practices within   │
# │  the community. Organizations and researchers are working to address biases  │
# │  prevalent in machine learning datasets, enhancing data transparency, and    │
# │  establishing comprehensive guidelines for responsible AI deployment.        │
# │  Initiatives aim to foster inclusivity, enhance fairness, and mitigate       │
# │  risks associated with AI misuse. Collaborations between academia,           │
# │  industry, and regulatory bodies are paving the way for standards that       │
# │  promote ethical considerations in model design, ensuring that LLMs          │
# │  contribute positively to society while protecting individual rights and     │
# │  privacy.                                                                    │
# │                                                                              │
# │  ## 6. Real-Time Interaction and Conversational AI                           │
# │  The advancements in real-time interaction and conversational capabilities   │
# │  for LLMs have reached a new zenith in 2024. AI systems are now capable of   │
# │  engaging users in dynamic, contextually aware dialogues, which enhances     │
# │  their application in customer service scenarios and virtual assistant       │
# │  platforms. These improvements are realized through advances in natural      │
# │  language understanding (NLU) and natural language generation (NLG)          │
# │  techniques, enabling systems to respond more fluidly and appropriately to   │
# │  user inputs. The augmented capacity for understanding temporal context and  │
# │  user intent means that businesses can offer richer, more personalized       │
# │  experiences, resulting in higher user satisfaction and engagement rates.    │
# │                                                                              │
# │  ## 7. Robustness Against Adversarial Attacks                                │
# │  As the reliance on AI systems grows, so too does the need for robust        │
# │  defenses against adversarial attacks. Developments in LLMs during 2024      │
# │  reflect substantial progress in enhancing model security against            │
# │  manipulative inputs designed to deceive AI systems. Researchers are         │
# │  experimenting with novel training methodologies that incorporate            │
# │  adversarial examples during the learning process, leading to models that    │
# │  exhibit improved resilience. The emphasis on robustness not only fortifies  │
# │  the integrity of AI outputs but also contributes to broader discussions     │
# │  surrounding trust and accountability in AI applications.                    │
# │                                                                              │
# │  ## 8. Interdisciplinary Applications                                        │
# │  The versatility of large language models has led to their successful        │
# │  application across various interdisciplinary fields, far beyond             │
# │  traditional language tasks. In healthcare, LLMs are facilitating accurate   │
# │  medical documentation and aiding in diagnostics by processing vast amounts  │
# │  of medical literature. In the legal domain, they are employed for contract  │
# │  analysis, risk assessment, and predictive legal outcomes. The finance       │
# │  sector is harnessing LLMs for portfolio management and fraud detection.     │
# │  These diverse applications underscore the transformative potential of AI    │
# │  technologies and their ability to streamline operations, improve            │
# │  decision-making, and enhance service delivery across sectors.               │
# │                                                                              │
# │  ## 9. Open-Source Collaboration                                             │
# │  The open-source movement remains a cornerstone of innovation within the AI  │
# │  LLM landscape in 2024. Communities such as Hugging Face and EleutherAI are  │
# │  pivotal in fostering collaboration, sharing resources, and advancing        │
# │  research. By providing accessible frameworks and enriching datasets to the  │
# │  broader community, these projects enable researchers and developers to      │
# │  build upon existing models, ensuring that advancements are democratized     │
# │  and not restricted to major corporations. This collaborative ethos          │
# │  accelerates the pace of innovation and encourages diverse contributions     │
# │  from individuals and institutions around the world.                         │
# │                                                                              │
# │  ## 10. Regulatory Considerations                                            │
# │  As the implications of AI technologies become more pronounced, regulatory   │
# │  frameworks are emerging to address the challenges posed by large language   │
# │  models. Governments and organizations are recognizing the urgent need to    │
# │  govern the ethical use of AI, with attention to data privacy, model         │
# │  transparency, and accountability. Policies aimed at mitigating risks        │
# │  associated with the deployment of AI technologies are being conceptualized  │
# │  and implemented, creating a structured approach to accountability and       │
# │  oversight. The establishment of regulatory protocols not only safeguards    │
# │  public interest but also fosters confidence in AI applications across       │
# │  industries.                                                                 │
# │                                                                              │
# │  This report encapsulates the current trends and developments shaping the    │
# │  field of AI large language models as of 2024. The intersection of           │
# │  technological innovation, ethical considerations, and regulatory            │
# │  frameworks presents a complex landscape that requires ongoing attention     │
# │  and collaboration among stakeholders to maximize benefits while mitigating  │
# │  risks associated with AI deployment.                                        │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: d6b3ea19-fc51-4316-8ca2-e4dc02d61089)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 06ab6486-9b83-4294-a71b-3ee5a394e158)
#     Assigned to: AI LLMs Reporting Analyst
#
#     Status: ✅ Completed
# ╭────────────────────────────── Task Completion ───────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name: reporting_task                                                        │
# │  Agent: AI LLMs Reporting Analyst                                            │
# │                                                                              │
# │  Tool Args:                                                                  │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── Crew Completion ───────────────────────────────╮
# │                                                                              │
# │  Crew Execution Completed                                                    │
# │  Name: crew                                                                  │
# │  ID: 5670c234-c0ed-4501-a028-1103e70128c4                                    │
# │  Tool Args:                                                                  │
# │  Final Output: # Report on Current Trends in AI Large Language Models        │
# │  (LLMs) - 2024                                                               │
# │                                                                              │
# │  ## 1. Increased Model Sizes                                                 │
# │  The trend towards scaling up the size of language models shows no signs of  │
# │  slowing down in 2024. Recent advancements have led to the development of    │
# │  LLMs that boast parameter counts reaching into the hundreds of billions.    │
# │  These expansive models exhibit a marked improvement in their capabilities   │
# │  for understanding context, generating coherent text, and addressing         │
# │  complex queries across various topics. The sheer size of these models       │
# │  enables them to capture intricate patterns in language, leading to          │
# │  enhanced performance in natural language processing tasks. Major players    │
# │  in the field, including OpenAI, Google, and Meta, continue to push the      │
# │  boundaries, fostering breakthroughs that contribute to more nuanced and     │
# │  contextually aware AI systems.                                              │
# │                                                                              │
# │  ## 2. Multimodal Capabilities                                               │
# │  In 2024, AI LLMs are increasingly integrating multimodal capabilities,      │
# │  demonstrating proficiency in processing and generating a variety of         │
# │  content types—text, images, and audio—within a single framework. Notable    │
# │  examples include models derived from GPT-4, which can analyze visual        │
# │  inputs and produce relevant textual descriptions or engage in dialogues     │
# │  that seamlessly incorporate graphical content. This advancement represents  │
# │  a significant step toward more holistic AI systems that can understand and  │
# │  interact with the world in a more human-like manner. The rise of            │
# │  multimodal models facilitates a broader range of applications, from         │
# │  immersive virtual experiences to enhanced assistive technologies for        │
# │  individuals with disabilities.                                              │
# │                                                                              │
# │  ## 3. Lowering Carbon Footprint                                             │
# │  As awareness of climate change intensifies, the AI community is making      │
# │  concerted efforts to address the carbon footprint associated with training  │
# │  large language models. Innovative energy-efficient architectures and        │
# │  training methodologies are being explored to minimize environmental         │
# │  impact. Research into techniques such as distillation, pruning, and         │
# │  low-rank factorization is ongoing, with a focus on reducing the             │
# │  computational resources required for effective model training.              │
# │  Additionally, collaborations with organizations dedicated to                │
# │  sustainability aim to optimize data center operations and promote the use   │
# │  of renewable energy sources in AI research and deployment.                  │
# │                                                                              │
# │  ## 4. Fine-Tuning and Customization                                         │
# │  Organizations across different sectors are increasingly focused on          │
# │  fine-tuning and customizing pre-trained LLMs to meet specific operational   │
# │  needs. This trend is fueled by the understanding that tailored models can   │
# │  yield superior performance without the need for extensive computational     │
# │  power or resources. Businesses are investing in user-friendly frameworks    │
# │  that streamline the fine-tuning process, enabling even small teams to       │
# │  adapt powerful models for unique applications, such as customer support     │
# │  chatbots or specialized content generation tools. This democratization of   │
# │  technology not only enhances productivity but also allows for more diverse  │
# │  representation in the use of AI solutions.                                  │
# │                                                                              │
# │  ## 5. Focus on Ethical AI                                                   │
# │  In 2024, there is an increasing commitment to ethical AI practices within   │
# │  the community. Organizations and researchers are working to address biases  │
# │  prevalent in machine learning datasets, enhancing data transparency, and    │
# │  establishing comprehensive guidelines for responsible AI deployment.        │
# │  Initiatives aim to foster inclusivity, enhance fairness, and mitigate       │
# │  risks associated with AI misuse. Collaborations between academia,           │
# │  industry, and regulatory bodies are paving the way for standards that       │
# │  promote ethical considerations in model design, ensuring that LLMs          │
# │  contribute positively to society while protecting individual rights and     │
# │  privacy.                                                                    │
# │                                                                              │
# │  ## 6. Real-Time Interaction and Conversational AI                           │
# │  The advancements in real-time interaction and conversational capabilities   │
# │  for LLMs have reached a new zenith in 2024. AI systems are now capable of   │
# │  engaging users in dynamic, contextually aware dialogues, which enhances     │
# │  their application in customer service scenarios and virtual assistant       │
# │  platforms. These improvements are realized through advances in natural      │
# │  language understanding (NLU) and natural language generation (NLG)          │
# │  techniques, enabling systems to respond more fluidly and appropriately to   │
# │  user inputs. The augmented capacity for understanding temporal context and  │
# │  user intent means that businesses can offer richer, more personalized       │
# │  experiences, resulting in higher user satisfaction and engagement rates.    │
# │                                                                              │
# │  ## 7. Robustness Against Adversarial Attacks                                │
# │  As the reliance on AI systems grows, so too does the need for robust        │
# │  defenses against adversarial attacks. Developments in LLMs during 2024      │
# │  reflect substantial progress in enhancing model security against            │
# │  manipulative inputs designed to deceive AI systems. Researchers are         │
# │  experimenting with novel training methodologies that incorporate            │
# │  adversarial examples during the learning process, leading to models that    │
# │  exhibit improved resilience. The emphasis on robustness not only fortifies  │
# │  the integrity of AI outputs but also contributes to broader discussions     │
# │  surrounding trust and accountability in AI applications.                    │
# │                                                                              │
# │  ## 8. Interdisciplinary Applications                                        │
# │  The versatility of large language models has led to their successful        │
# │  application across various interdisciplinary fields, far beyond             │
# │  traditional language tasks. In healthcare, LLMs are facilitating accurate   │
# │  medical documentation and aiding in diagnostics by processing vast amounts  │
# │  of medical literature. In the legal domain, they are employed for contract  │
# │  analysis, risk assessment, and predictive legal outcomes. The finance       │
# │  sector is harnessing LLMs for portfolio management and fraud detection.     │
# │  These diverse applications underscore the transformative potential of AI    │
# │  technologies and their ability to streamline operations, improve            │
# │  decision-making, and enhance service delivery across sectors.               │
# │                                                                              │
# │  ## 9. Open-Source Collaboration                                             │
# │  The open-source movement remains a cornerstone of innovation within the AI  │
# │  LLM landscape in 2024. Communities such as Hugging Face and EleutherAI are  │
# │  pivotal in fostering collaboration, sharing resources, and advancing        │
# │  research. By providing accessible frameworks and enriching datasets to the  │
# │  broader community, these projects enable researchers and developers to      │
# │  build upon existing models, ensuring that advancements are democratized     │
# │  and not restricted to major corporations. This collaborative ethos          │
# │  accelerates the pace of innovation and encourages diverse contributions     │
# │  from individuals and institutions around the world.                         │
# │                                                                              │
# │  ## 10. Regulatory Considerations                                            │
# │  As the implications of AI technologies become more pronounced, regulatory   │
# │  frameworks are emerging to address the challenges posed by large language   │
# │  models. Governments and organizations are recognizing the urgent need to    │
# │  govern the ethical use of AI, with attention to data privacy, model         │
# │  transparency, and accountability. Policies aimed at mitigating risks        │
# │  associated with the deployment of AI technologies are being conceptualized  │
# │  and implemented, creating a structured approach to accountability and       │
# │  oversight. The establishment of regulatory protocols not only safeguards    │
# │  public interest but also fosters confidence in AI applications across       │
# │  industries.                                                                 │
# │                                                                              │
# │  This report encapsulates the current trends and developments shaping the    │
# │  field of AI large language models as of 2024. The intersection of           │
# │  technological innovation, ethical considerations, and regulatory            │
# │  frameworks presents a complex landscape that requires ongoing attention     │
# │  and collaboration among stakeholders to maximize benefits while mitigating  │
# │  risks associated with AI deployment.                                        │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
#
#
# ╭────────────────────────────── Execution Traces ──────────────────────────────╮
# │                                                                              │
# │  🔍 Detailed execution traces are available!                                 │
# │                                                                              │
# │  View insights including:                                                    │
# │    • Agent decision-making process                                           │
# │    • Task execution flow and timing                                          │
# │    • Tool usage details                                                      │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# Would you like to view your execution traces? [y/N] (20s timeout):

# %% [markdown]
# ## Flows CLI - Command Line Interface

# %%
! crewai create flow new_flow
# Out:
# Creating flow new_flow...
# Flow new_flow created successfully!

# %%
! ls -1 new_flow
# Out:
# README.md
# pyproject.toml
# src
# tests

# %%
! ls -1 new_flow/src/new_flow/
# Out:
# __init__.py
# crews
# main.py
# tools
